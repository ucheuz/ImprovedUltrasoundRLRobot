# %%
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import pybullet as p
import math
import random
import time
print("basic imports ok")
# Out:
# basic imports ok

# %%
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
print("sb3 ok")
# Out:
# sb3 ok

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\kdsaj\anaconda3\envs\ultrasound310\python.exe

# %%
# %matplotlib inline

# %%
# functions nessersary 
import numpy as np
import math 

# Converts Euler angles ([rx, ry, rz] in deg) to a 3x3 rotation matrix
def EulerToRMat(Euler):

    sx = math.sin(Euler[0]);
    sy = math.sin(Euler[1]);
    sz = math.sin(Euler[2]);
    cx = math.cos(Euler[0]);
    cy = math.cos(Euler[1]);
    cz = math.cos(Euler[2]);

    RMat = np.eye(3);
    RMat[0,0] = cy*cz;
    RMat[0,1] = sx*sy*cz-cx*sz;
    RMat[0,2] = cx*sy*cz+sx*sz;
    RMat[1,0] = cy*sz;
    RMat[1,1] = sx*sy*sz+cx*cz;
    RMat[1,2] = cx*sy*sz-sx*cz;
    RMat[2,0] = -sy;
    RMat[2,1] = sx*cy;
    RMat[2,2] = cx*cy;

    return RMat

# Converts a 3x3 rotation matrix to a quaternion
def RMatToQuat(RMat):

    quat = np.zeros((4,1));

    # abs is to avoid rounding errors in the sqrt - it shouldn't be negative anyway
    quat[0] = 0.5 * math.sqrt(abs(1 + RMat[0,0] + RMat[1,1] + RMat[2,2]));

    if (RMat[2,1] - RMat[1,2] > 0):
        quat[1] = 0.5 * math.sqrt(abs(1 + RMat[0,0] - RMat[1,1] - RMat[2,2]));
    else:
        quat[1] = -0.5 * math.sqrt(abs(1 + RMat[0,0] - RMat[1,1] - RMat[2,2]));


    if (RMat[0,2] - RMat[2,0] > 0):
        quat[2] = 0.5 * math.sqrt(abs(1 - RMat[0,0] + RMat[1,1] - RMat[2,2]));
    else:
        quat[2] = -0.5 * math.sqrt(abs(1 - RMat[0,0] + RMat[1,1] - RMat[2,2]));

    if (RMat[1,0] - RMat[0,1] > 0):
        quat[3] = 0.5 * math.sqrt(abs(1 - RMat[0,0] - RMat[1,1] + RMat[2,2]));
    else:
        quat[3] = -0.5 * math.sqrt(abs(1 - RMat[0,0] - RMat[1,1] + RMat[2,2]));

    return quat

# caclulating difference in Quaternions angles 
def quatDiff(q1, q2):
        
    # Difference: qd = q2 * q1c (q1c = conjugate of q1 = inverse of q1)
    # qd = (w2 + i.x2 + j.y2 + k.z2)(w1 - i.x1 - j.y1 - k.z1)
    # qd = w1.w2 - i.x1.w2 - j.y1.w2 - k.z1.w2 + i.w1.x2 - i^2.x1.x2 - ij.y1.x2 - ik.z1.x2 + j.w1.y2 - ji.x1.y2 - j^2.y1.y2 - jk.z1.y2 + k.w1.z2 - ki.x1.z2 - kj.y1.z2 - k^2.z1.z2
    # qd(1) =  w1.w2 + x1.x2 + y1.y2 + z1.z2
    # qd(2) = -x1.w2 + w1.x2 - z1.y2 + y1.z2
    # qd(3) = -y1.w2 + z1.x2 + w1.y2 - x1.z2
    # qd(4) = -z1.w2 - y1.x2 + x1.y2 + w1.z2

    qd = np.zeros((4,1));
    qd[0] =  q1[0]*q2[0] + q1[1]*q2[1] + q1[2]*q2[2] + q1[3]*q2[3]
    qd[1] = -q1[1]*q2[0] + q1[0]*q2[1] - q1[3]*q2[2] + q1[2]*q2[3]
    qd[2] = -q1[2]*q2[0] + q1[3]*q2[1] + q1[0]*q2[2] - q1[1]*q2[3]
    qd[3] = -q1[3]*q2[0] - q1[2]*q2[1] + q1[1]*q2[2] + q1[0]*q2[3]

    a = 2 * np.arccos(np.float32(qd[0]))

    a = abs(a);

    return a, qd

# normalisation function between -1 and +1  
def normalise(x, min_val, max_val):

    # equation for normalisation 
    x_n = (2 * (x - min_val) / (max_val - min_val)) - 1

    return x_n

# %%
def check_cross_arm_collision_env(bc, robot, threshold=0.02):
    collisions = []
    for i in range(2, 11):
        for j in range(12, 21):
            pts = bc.getClosestPoints(
                bodyA=robot,
                bodyB=robot,
                distance=threshold,
                linkIndexA=i,
                linkIndexB=j
            )
            if len(pts) > 0:
                collisions.append((i, j))
    return collisions


def check_cross_arm_contact_env(bc, robot):
    contacts = []
    for i in range(2, 11):
        for j in range(12, 21):
            pts = bc.getContactPoints(
                bodyA=robot,
                bodyB=robot,
                linkIndexA=i,
                linkIndexB=j
            )
            if len(pts) > 0:
                contacts.append((i, j))
    return contacts


def check_arm_base_collision_env(bc, robot, threshold=0.02):
    collisions = []
    base_links = [0, 1, 11]

    for i in range(2, 11):
        for j in base_links:
            pts = bc.getClosestPoints(
                bodyA=robot,
                bodyB=robot,
                distance=threshold,
                linkIndexA=i,
                linkIndexB=j
            )
            if len(pts) > 0:
                collisions.append(("L", i, j))

    for i in range(12, 21):
        for j in base_links:
            pts = bc.getClosestPoints(
                bodyA=robot,
                bodyB=robot,
                distance=threshold,
                linkIndexA=i,
                linkIndexB=j
            )
            if len(pts) > 0:
                collisions.append(("R", i, j))

    return collisions


def collision_summary_env(bc, robot, threshold=0.02):
    cross_arm = check_cross_arm_collision_env(bc, robot, threshold)
    cross_contact = check_cross_arm_contact_env(bc, robot)
    arm_base = check_arm_base_collision_env(bc, robot, threshold)

    proximity_penalty = len(cross_arm) + len(arm_base)
    contact_penalty = 10 * len(cross_contact)
    total_penalty = proximity_penalty + contact_penalty

    return {
        "cross_arm": cross_arm,
        "cross_contact": cross_contact,
        "arm_base": arm_base,
        "proximity_penalty": proximity_penalty,
        "contact_penalty": contact_penalty,
        "total_penalty": total_penalty,
    }

# %%
## creating an environment class (child class to gym.Env) for the Ultrasound Robot
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import pybullet as p 
import pybullet_utils.bullet_client as bullet_client
import random
import math
import matplotlib.pyplot as plt
import time

class RightArmRobot(gym.Env):
    """
    Custom Environment that follows gym interface.
    """

    # (old comment) Because of google colab, we cannot implement the GUI ('human' render mode)
    metadata = {"render_modes": ["human", "rgb_array"], "simulation_fps": 50} # PyBullet simulation FPS

    def __init__(self, render_mode="human"):

        # calls constructor of parent class gym.Env         
        super(RightArmRobot, self).__init__()
        
        # setting up the render mode for visualisation 
        self.render_mode = render_mode

        # Initialize PyBullet client ID
        self._physics_client_id = -1  
        
        # initialsiing the action space as continous (action is angles of all 9 motorised joints) 
        self.action_space = spaces.Box(low=-1, high=1, shape=(20,), dtype=np.float32) # change to 20 once URDF is updated for 2 arms
        # initialising the observation space as continous (observation is cartesian coordiantes of final joint in the robot)
        self.observation_space = spaces.Box(low = -10, high = 10, shape=(34,), dtype=np.float32)

        # tolerance for goal completion (position)
        self.pos_tol = 0.02

        # tolerance for goal completion (orientation)
        self.orient_tol = 0.2

        # initalising step number 
        self.step_number = 0

        # initalising the episode number 
        self.episode_number = 0 

        # initalise the max step number 
        self.max_step_size = 100

        # collision number inialisation 
        self.collisions = 0

        # rest function called to properly initalise the 
        self.render_mode = render_mode
        self._bullet_client = None
        self._physics_client_id = -1

    def reset(self, seed=None, options=None):

        # re-initalisation of environment after truncation, termination or initalisation

        # reset step number and print
        self.step_number = 0
        self.collisions = 0

        # increase the episode number 
        self.episode_number += 1

        # initalising the prev Euclidean distance
        self.prev_Euclid_dist = 0

        # calls constructor of parent class gym.Env 
        super().reset(seed=seed, options=options)

        # random number generator to provide new target for the robot to move to (set limits)
        self.x_target1 = random.random()*(0.15 - -0.10) 
        self.y_target1 = random.random()*(0.65 - 0.3) + (0.3) 
        self.z_target1 = random.random()*(0.35 - 0.15) + (0.15) 
        self.pos_target1 = np.array([self.x_target1, self.y_target1, self.z_target1], dtype=np.float32)

        # position target for the second arm 
        self.x_target2 = random.random()*(0.15 - -0.10) 
        self.y_target2 = random.random()*(0.65 - 0.3) + (0.3) 
        self.z_target2 = random.random()*(0.35 - 0.15) + (0.15) 
        self.pos_target2 = np.array([self.x_target2, self.y_target2, self.z_target2], dtype=np.float32)

        # New ORIENTATION target (in Euler angles) for the robot to move to (set limits)
        self.x_euler_t1 = random.random()*(-0.785398 - -2.35619)
        self.y_euler_t1 = random.random()*(0.785398 - -0.785398)
        self.z_euler_t1 = random.random()*(math.pi - -math.pi)
        self.euler_t1 = np.array([self.x_euler_t1, self.y_euler_t1, self.z_euler_t1])

        # angle target for the second arm 
        self.x_euler_t2 = random.random()*(-0.785398 - -2.35619)
        self.y_euler_t2 = random.random()*(0.785398 - -0.785398)
        self.z_euler_t2 = random.random()*(math.pi - -math.pi)
        self.euler_t2 = np.array([self.x_euler_t2, self.y_euler_t2, self.z_euler_t2])

        # Converting the target Euler angles into Matrix 
        self.Mat_t1 = EulerToRMat(self.euler_t1)
        self.Mat_t2 = EulerToRMat(self.euler_t2)
        # Converting the target Matrix into Quaternion
        self.Quat_t1 = RMatToQuat(self.Mat_t1)
        self.Quat_t2 = RMatToQuat(self.Mat_t2)
        
        # setup PyBullet client 
        
        if self._physics_client_id < 0 or self._bullet_client is None:
             if self.render_mode == "human":
                 self._bullet_client = bullet_client.BulletClient(connection_mode=p.GUI)
             else:
                 self._bullet_client = bullet_client.BulletClient(connection_mode=p.DIRECT)

             self._physics_client_id = self._bullet_client._client

        # setting up PyBullet simulation 
        self._bullet_client.resetSimulation()
        self._bullet_client.setGravity(0, 0, -9.8)
        self._bullet_client.setTimeStep(1.0 / self.metadata["simulation_fps"])

        # load robot 
        self._bullet_client.setAdditionalSearchPath(r"C:\Users\kdsaj\OneDrive\Desktop\ultrasound_project\Ultrasound-project-Git\Two_arm_Git")
        self.RightArmRobot = self._bullet_client.loadURDF("TwoArms_col.urdf",[0, 0, 0], useFixedBase=True)

        # check if loading of the robot was sucessful 
        if self.RightArmRobot < 0:
            raise FileNotFoundError("Failed to load kuka_3.urdf. Check the file path.")

        # Check the number of joints
        self.num_joints = self._bullet_client.getNumJoints(self.RightArmRobot)
        # print(self.num_joints)
        

        # Validate link index
        link_index = 9
        if link_index >= self.num_joints:
            raise IndexError(f"Invalid link index {link_index}. Max index is {self.num_joints - 1}.")

        # Get link state
        link_state = self._bullet_client.getLinkState(self.RightArmRobot, link_index)
        if link_state is None:
            raise RuntimeError(f"Failed to get link state for link {link_index}.")

        # Find and print link information (for debugging)
        #for i in range(num_joints):
             #joint_name = self._bullet_client.getJointInfo(self.RightArmRobot, i)[12].decode('utf-8')  # Get joint name
             #link_index = self._bullet_client.getJointInfo(self.RightArmRobot, i)[16] # Get link index
             #if link_index != -1: # if the joint has an associated link
                 #link_name = self._bullet_client.getLinkInfo(self.RightArmRobot,link_index)[0].decode('utf-8')
                #print(f"Joint {i}: {joint_name}, Link index: {link_index}, Link Name: {link_name}")

        # get the position of links of interst 
        link_index1 = 12
        link_index2 = self.num_joints - 1
        
        link_state1 = self._bullet_client.getLinkState(self.RightArmRobot, link_index1)
        link_state2 = self._bullet_client.getLinkState(self.RightArmRobot, link_index2)
        
        # extracting the x y z position 
        self.position1 = np.array(link_state1[0], dtype=np.float32)
        self.position2 = np.array(link_state2[0], dtype=np.float32)

        # extracting the orientation as a Quaternion
        self.orientation1 = np.array(link_state1[1], dtype=np.float32)
        self.orientation2 = np.array(link_state2[1], dtype=np.float32)
        
        # calculating initial distances from the targets 
        self.Euclid_dist1 = math.dist(self.position1, self.pos_target1)
        self.Euclid_dist2 = math.dist(self.position2, self.pos_target2)
        
        # calculating angular differences from targets 
        self.Quaternion_diff1 = quatDiff(self.orientation1, self.Quat_t1)
        self.Quat_diff_angle1 = self.Quaternion_diff1[0]
        self.Quat_diff_Q1 = self.Quaternion_diff1[1]

        self.Quaternion_diff2 = quatDiff(self.orientation2, self.Quat_t2)
        self.Quat_diff_angle2 = self.Quaternion_diff2[0]
        self.Quat_diff_Q2 = self.Quaternion_diff2[1]

        # normalising position such that observations are more easily computeable in RL neural networks
        # normalising target positions 
        self.x_target_n1 = normalise(self.x_target1, -0.10, 0.15)
        self.y_target_n1 = normalise(self.y_target1, 0.3, 0.65)
        self.z_target_n1 = normalise(self.z_target1, 0.15, 0.35)
        self.pos_target_n1 = np.array([self.x_target_n1, self.y_target_n1, self.z_target_n1], dtype=np.float32)

        self.x_target_n2 = normalise(self.x_target2, -0.10, 0.15)
        self.y_target_n2 = normalise(self.y_target2, 0.3, 0.65)
        self.z_target_n2 = normalise(self.z_target2, 0.15, 0.35)
        self.pos_target_n2 = np.array([self.x_target_n2, self.y_target_n2, self.z_target_n2], dtype=np.float32)
        
        # normalising actual positions 
        self.x_pos_n = normalise(self.position1[0], -0.10, 0.15)
        self.y_pos_n = normalise(self.position1[1], 0.3, 0.65)
        self.z_pos_n = normalise(self.position1[2], 0.15, 0.35)
        self.pos_n1 = np.array([self.x_pos_n, self.y_pos_n, self.z_pos_n], dtype=np.float32)
        self.pos_n2 = self.pos_n1
         
        
        # self.observation MUST be a numpy array 
        # observation is the euclidean distance, the quaternion difference, the target positions, the current positions, target orientation, current orientation 
        self.observation = np.concatenate([
          np.zeros(20, dtype=np.float32),  # joint states placeholder
          self.position1,
          self.position2,
          self.pos_target1,
          self.pos_target2,
          np.array([self.Euclid_dist1, self.Euclid_dist2], dtype=np.float32)
        ]).astype(np.float32)
         
        
        return self.observation, {}
        

    def step(self, action):

        # takes an action in a given state

        # updating the step counter each step and printing
        self.step_number += 1

        # inialise convergence of each arm
        self.arm_left_conv = False
        self.arm_right_conv = False

        # initalising the scaled action variable to have the dimensions of the actions 
        scaled_action = action

        # scale action by pi 
        for i in range(20):
            if (i == 0):
                scaled_action[i] = action[i] / 4
            else:
                scaled_action[i] = action[i] * np.pi 

        # applying dependent joint constraints to both arms  
        scaled_action[3] = -scaled_action[2]
        scaled_action[13] = -scaled_action[12]
        
        # Apply action to robot
        for i in range(20):  # iterating through all joints of both arms of the robot
            if (i == 1): # skip the non moving joint
                continue
            self._bullet_client.setJointMotorControl2(
                self.RightArmRobot, i, p.POSITION_CONTROL, targetPosition=scaled_action[i]
                )
            
        # use for loop for updating to ensure that the robot can move by the amount it needs to move 
        for _ in range(3):
            # Robots new position is updated in the simulation  
            self._bullet_client.stepSimulation()

        
        #link_index0 = 0
        #link_state0 = self._bullet_client.getLinkState(self.RightArmRobot, link_index0)
        #position0 = np.array(link_state0[0], dtype=np.float32)
        #print(position0)

        joint_states = [self._bullet_client.getJointState(self.RightArmRobot, i)[0] for i in range(20)]
        joint_states = np.array(joint_states, dtype=np.float32)
        
        # Gives position of the final link of the 1st arm Robot in Cartesian space
        link_state1 = self._bullet_client.getLinkState(self.RightArmRobot, 10)
        
        # Position and orienatation are the observation to be changed 
        self.position1 = np.array(link_state1[0], dtype=np.float32)
        self.orientation1 = np.array(link_state1[1], dtype=np.float32)

        # Gives position of the final link of the 2nd arm Robot in Cartesian space
        link_state2 = self._bullet_client.getLinkState(self.RightArmRobot, 20)

        # Position and orientation are the observation to be changed 
        self.position2 = np.array(link_state2[0], dtype=np.float32)
        self.orientation2 = np.array(link_state2[1], dtype=np.float32)

        # normalising actual positions 
        self.x_pos_n1 = normalise(self.position1[0], -0.10, 0.15) # first arm position  
        self.y_pos_n1 = normalise(self.position1[1], 0.3, 0.65)
        self.z_pos_n1 = normalise(self.position1[2], 0.15, 0.35)

        self.x_pos_n2 = normalise(self.position2[0], -0.10, 0.15) # second arm position 
        self.y_pos_n2 = normalise(self.position2[1], 0.3, 0.65)
        self.z_pos_n2 = normalise(self.position2[2], 0.15, 0.35)
        
        self.pos_n1 = np.array([self.x_pos_n1, self.y_pos_n1, self.z_pos_n1], dtype=np.float32)
        self.pos_n2 = np.array([self.x_pos_n2, self.y_pos_n2, self.z_pos_n2], dtype=np.float32)

        # calculating the Euclidian distance for reward calculation
        self.Euclid_dist1 = math.dist(self.position1, self.pos_target1)
        self.Euclid_dist2 = math.dist(self.position2, self.pos_target2)
        self.Euclid_distT = [self.Euclid_dist1, self.Euclid_dist2]
        
        # calculating the Quaternion difference for first arm for reward calculation 
        self.Quaternion_diff1 = quatDiff(self.orientation1, self.Quat_t1)
        self.Quat_diff_angle1 = self.Quaternion_diff1[0].item()
        self.Quat_diff_Q1 = self.Quaternion_diff1[1]

        # calculating the Quaternion difference for second arm for reward calculation
        self.Quaternion_diff2 = quatDiff(self.orientation2, self.Quat_t2)
        self.Quat_diff_angle2 = self.Quaternion_diff2[0].item()
        self.Quat_diff_Q2 = self.Quaternion_diff2[1]

        # overall angle 
        self.Quat_diff_angleT = [self.Quat_diff_angle1, self.Quat_diff_angle2]

        # observation is the euclidean distance, the quaternion difference, the target positions, the current positions,target orientation, current orientation 
        self.observation = np.concatenate([
            joint_states,
            self.position1,
            self.position2,
            self.pos_target1,
            self.pos_target2,
            np.array([self.Euclid_dist1, self.Euclid_dist2], dtype=np.float32)
        ]).astype(np.float32)
        
        # new observation stored in variable obs  
        obs = self.observation

        # normalising the Euclidean distance to 0-1 (dividing by maximum Euclidean distance)
        self.Euclid_dist_n1 = (self.Euclid_dist1 / 0.7533)
        self.Euclid_dist_n2 = (self.Euclid_dist2 / 0.7533)

        # normalising the angular difference to 0-1 (dividing by the radians)
        self.Quat_diff_angle_n1 = self.Quat_diff_angle1 / (2 * np.pi)
        self.Quat_diff_angle_n2 = self.Quat_diff_angle2 / (2 * np.pi)
        
        # calculating the reward (sum of the Euclidean distance and the Quaternion difference)
        self.rew_left = - (self.Euclid_dist_n1 + self.Quat_diff_angle_n1)
        self.rew_right = - (self.Euclid_dist_n2 + self.Quat_diff_angle_n2)
        reward = self.rew_left + self.rew_right
        
        # collect as a prev Euclidean Distance 
        self.prev_Euclid_dist = self.Euclid_dist1

        # collison criteria  
        summary = collision_summary_env(self._bullet_client, self.RightArmRobot)

        # apply penalty
        reward -= summary["total_penalty"] * 5

        # optional: strong penalty for actual contact
        if summary["contact_penalty"] > 0:
           reward -= 50
           print("Hard collision detected")

        # logging
        self.collisions += summary["total_penalty"]

        # convergence criteria 
        if ((self.Euclid_dist1 < self.pos_tol) and (self.Quat_diff_angle1 < self.orient_tol) and (self.arm_left_conv == False)):
            # large reward for convergence 
            reward += 240
            self.rew_left += 240
            self.arm_left_conv = True 

        if ((self.Euclid_dist2 < self.pos_tol) and (self.Quat_diff_angle2 < self.orient_tol) and (self.arm_right_conv == False)):
            # large reward for convergence
            reward += 240
            self.rew_right += 240 
            self.arm_right_conv = True

        if ((self.Euclid_dist1 < self.pos_tol) and (self.Quat_diff_angle1 < self.orient_tol) and (self.Euclid_dist2 < self.pos_tol) and (self.Quat_diff_angle2 < self.orient_tol)):
            # large reward for termination 
            reward += 500 
            self.rew_indv = [self.rew_left, self.rew_right]
            terminated = True 

        else:
            terminated = False 
        
        # truncation criteria
        if (self.step_number < self.max_step_size):          
            truncated = False
        else:
            self.rew_indv = [self.rew_left, self.rew_right]
            truncated = True 

        self.rew_indv = [self.rew_left, self.rew_right]
            
        # updating the info dictionary 
        info = {"Truncated":truncated,"Terminated":terminated,"Observations":obs,"EuclidDist":self.Euclid_distT,"AngleDiff":self.Quat_diff_angleT,"Collisions": summary["total_penalty"],"LeftArmConv":self.arm_left_conv,"RightArmConv":self.arm_right_conv,"RewardsIndv":self.rew_indv}            
        
        # returning all step variables in a tuple 
        return obs, reward, terminated, truncated, info

# %%
from stable_baselines3.common.monitor import Monitor

env = Monitor(RightArmRobot(render_mode="human"))
print("env ready")
# Out:
# env ready

# %%
from stable_baselines3 import SAC

model = SAC.load("dual_arm_model_obs34", env=env)
print("model ready")
# Out:
# Wrapping the env in a DummyVecEnv.
# model ready

# %%
obs, _ = env.reset()
print("reset done")
# Out:
# reset done

# %%
env = Monitor(RightArmRobot(render_mode=None))

# %%
from stable_baselines3 import SAC
model = SAC("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
action, _ = model.predict(obs, deterministic=True)
print("action ready")
# Out:
# action ready

# %%
obs, _ = env.reset()
print("reset done")
# Out:
# reset done

# %%
obs, reward, terminated, truncated, info = env.step(action)
print("step done")
# Out:
# step done

# %%
for _ in range(100):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        obs, _ = env.reset()

print("simulation complete")
# Out:
# simulation complete

# %%
from stable_baselines3 import SAC

model = SAC("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
env = Monitor(RightArmRobot(render_mode=None))
print("env created")
# Out:
# env created

# %%
obs, _ = env.reset()

for _ in range(200):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        obs, _ = env.reset()

# %%
model.set_env(env)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -340     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 46       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -27.9    |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -2.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -315     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 40       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 3.64     |
# |    ent_coef        | 0.812    |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------

# %%
model.save("dual_arm_model_obs34")

# %%
print("kernel alive")
# Out:
# kernel alive

# %%
model = SAC.load("dual_arm_model_obs34", env=env)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
obs, _ = env.reset()

for _ in range(50):
    action, _ = model.predict(obs)
    obs, reward, done, truncated, info = env.step(action)

# %%
# defining the custom callback 
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy

class CustomCallback(BaseCallback):
    
    # initalisation of callback 
    def __init__(self, log_dir=None, verbose: int = 0):
        super().__init__(verbose)
        
        # initalisation of variables 
        self.timesteps = 0
        self.cum_rewards = 0
        self.episode_rewards = []
        self.episode_rewards_L = []
        self.episode_rewards_R = []
        self.number_of_episodes = 0
        self.log_dir = log_dir
        self.terminations = 0
        self.episode_timesteps = 0
        self.episode_termination = []
        self.final_Euclid_dists = []
        self.final_Euclid_dists1 = []
        self.final_Euclid_dists2 = []
        self.final_Quat_diffs = []
        self.final_Quat_diffs1 = []
        self.final_Quat_diffs2 = [] 
        self.change_Quat_diffs1 = []
        self.change_Quat_diffs2 = []
        self.mean_rewards = []
        self.std_rewards = [] 
        self.num_term_per_100 = 0
        self.num_term_per_100_L = []
        self.arm_left_conv = 0
        self.arm_right_conv = 0
        self.cum_rewards_L = 0
        self.cum_rewards_R = 0
        
    def _on_step(self) -> bool:

        # extracting info dictionary 
        info = self.locals["infos"][0]

        # extracting the Euclidean distance 
        Euclid_dist = info.get("EuclidDist")
        Euclid_dist1 = Euclid_dist[0]
        Euclid_dist2 = Euclid_dist[1] 
        Quat_diff = info.get("AngleDiff")
        Quat_diff1 = Quat_diff[0]
        Quat_diff2 = Quat_diff[1]
        
        # checking to see if it is the first timestep 
        if (self.episode_timesteps == 0):
            self.initial_Euclid_dist1 = Euclid_dist1
            self.initial_Euclid_dist2 = Euclid_dist2
            self.initial_Quat_diff1 = Quat_diff1
            self.initial_Quat_diff2 = Quat_diff2
        
        # update the timestep counter
        self.timesteps += 1
        self.episode_timesteps += 1

        # Access the "dones" array, which contains termination flags
        if "dones" in self.locals:
            done = self.locals["dones"][0]  # Extract first element (assuming non-parallel env)
        else:
            raise KeyError("Missing 'dones' in self.locals. Check environment compatibility.")

        # see whether the episode has finished  
        if done:
            
            # appending the episode number counter 
            self.number_of_episodes += 1
            # appending the episode reward counters
            self.episode_rewards.append(self.cum_rewards)
            self.episode_rewards_L.append(self.cum_rewards_L)
            self.episode_rewards_R.append(self.cum_rewards_R)
            # resetting the cumulative reward counters to 0 
            self.cum_rewards = 0
            self.cum_rewards_L = 0
            self.cum_rewards_R = 0
            self.episode_timesteps = 0

            # seeing if eithier arm reached the targets and update
            if info.get("LeftArmConv") == True:
                self.arm_left_conv += 1

            if info.get("RightArmConv") == True:
                self.arm_right_conv += 1

            # recording the final Euclidean distances
            self.final_Euclid_dists1.append(Euclid_dist1)
            self.final_Euclid_dists2.append(Euclid_dist2)
            self.final_Euclid_dists.append(Euclid_dist1 + Euclid_dist2)

            # recording the final Quaternion differences 
            self.final_Quat_diffs1.append(Quat_diff1) 
            self.final_Quat_diffs2.append(Quat_diff2)
            self.final_Quat_diffs.append(Quat_diff1 + Quat_diff2)
            
            # checking to see if robot reached target
            info = self.locals["infos"][0]
            if info.get("Terminated") is True:
                self.terminations += 1 
                self.num_term_per_100 += 1
                self.episode_termination.append(self.number_of_episodes)

            # checking if 100,000 timesteps is reached 
            if (self.timesteps % 100000 == 0): 
                # evaluating policy 
                mean_reward, std_reward = evaluate_policy(self.model, self.training_env, n_eval_episodes=100)
                self.mean_rewards.append(mean_reward)
                self.std_rewards.append(std_reward)
                self.num_term_per_100_L.append(self.num_term_per_100)
                

        
        # record the reward of the step taken 
        reward = self.locals["rewards"]
        self.cum_rewards += reward
        self.indv_rew = info.get("RewardsIndv")
        self.left_rew = self.indv_rew[0]
        self.right_rew = self.indv_rew[1]
        self.cum_rewards_L += self.left_rew
        self.cum_rewards_R += self.right_rew 
    
            
        return True 

    def _on_training_end(self) -> None:

        # Save episode rewards to a text file
        #with open("trial1.txt", "w") as file:
        #    for reward in self.episode_rewards:
        #        file.write(f"{reward}\n")

        # extracting info dictionary 
        info = self.locals["infos"][0]

        # save rewards to text file
        np.savetxt('reward_j.txt', np.array(self.episode_rewards))

        # save Left arm rewards to text file 
        np.savetxt('reward_L.txt', np.array(self.episode_rewards_L))

        # save Right arm rewards to text file
        np.savetxt('reward_R.txt', np.array(self.episode_rewards_R))

        # save final Euclidean distance as text file
        np.savetxt('fEuclid_j.txt', np.array(self.final_Euclid_dists))

        # save final Left Euclidean distance as text file 
        np.savetxt('fEuclid_L_j.txt', np.array(self.final_Euclid_dists1))

        # save final Right Euclidean distance as text file 
        np.savetxt('fEuclid_R_j.txt', np.array(self.final_Euclid_dists2))

        # save final Quaternion diff
        np.savetxt('fQuat_j.txt', np.array(self.final_Quat_diffs))

        # save final Quaternion diff (Left) as text file 
        np.savetxt('fQuat_L_j.txt', np.array(self.final_Quat_diffs1))

        # save final Quaternion diff (Right) as text file 
        np.savetxt('fQuat_R_j.txt', np.array(self.final_Quat_diffs2))

        # save mean reward values
        np.savetxt('mreward_j.txt', np.array(self.mean_rewards))

        # save std reward values 
        np.savetxt('std_rew_j.txt', np.array(self.std_rewards))

        # save number of terms per 100,000
        np.savetxt('num_term_per_100_j', np.array(self.num_term_per_100_L))
        
        # printing the number of terminations and the number of total episodes
        print("Number of episodes: ", self.number_of_episodes)
        print("Number of terminations: ", self.terminations)
        print("Number of collisions: ", info.get("Collisions"))
        print("Number of Left Arm Convergences: ", self.arm_left_conv)
        print("Number of Right Arm Convergences: ", self.arm_right_conv)

        # plotting graphs
        plt.figure(figsize=(15,5))

        # rewards vs episode number 
        plt.subplot(2,3,1)
        plt.plot(self.episode_rewards)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Cumulative Reward")
        plt.title("Cummalative Rewards VS Episode Number")

        # final Euclidean distance vs episode number 
        plt.subplot(2,3,2)
        plt.plot(self.final_Euclid_dists1)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Euclidean Distance (m)")
        plt.title("Final Euclidean Distance (L) VS Episode Number")

        # change in Euclidean distance vs episode number 
        plt.subplot(2,3,3)
        plt.plot(self.final_Euclid_dists2)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Euclidean Distance (m)")
        plt.title("Final Euclidean Distance (R) VS Episode Number")

        # final Quaternion difference vs episode number 
        plt.subplot(2,3,4)
        plt.plot(self.final_Quat_diffs1)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Quaternion Difference (rad)")
        plt.title("Final Quaternion Difference (L) VS Episode Number")

        # change in Quaternion Difference vs episode number 
        plt.subplot(2,3,5)
        plt.plot(self.final_Quat_diffs2)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Quaternion Difference (rad)")
        plt.title("Final Quaternion Difference (R) VS Episode Number")

        plt.subplot(2,3,6)
        plt.plot(self.cum_rewards_L)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Rewards")
        plt.title("Rewards (Left Arm) VS Episode Number")

        plt.tight_layout()
        plt.show

# %%
import numpy as np

# %%
# wrapping environment 
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
import os

# instantiating an array containing the mean rewards and standard deviation to be computed at the end of each set of 100,000 steps 
mean_rewards_arr = np.array(range(10))
std_rewards_arr = np.array(range(10))

# instantiate the robot arm custom environment and wrap with a monitor wrapper  
env = Monitor(RightArmRobot())

# %%
from stable_baselines3 import SAC

model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=50000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -299     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 35       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -28.1    |
# |    critic_loss     | 3.38     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -298     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 32       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 2.4      |
# |    ent_coef        | 0.812    |
# |    ent_coef_loss   | -6.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -285     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 31       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -49.3    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.722    |
# |    ent_coef_loss   | -10.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -271     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 31       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -58.3    |
# |    critic_loss     | 2.78     |
# |    ent_coef        | 0.642    |
# |    ent_coef_loss   | -14      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -264     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 30       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -65.9    |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.57     |
# |    ent_coef_loss   | -17.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -257     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 30       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -72      |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.507    |
# |    ent_coef_loss   | -21      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -252     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 30       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -76.2    |
# |    critic_loss     | 2.35     |
# |    ent_coef        | 0.451    |
# |    ent_coef_loss   | -24.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 30       |
# |    time_elapsed    | 104      |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -79.3    |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -27.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -244     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 30       |
# |    time_elapsed    | 118      |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -81.6    |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.358    |
# |    ent_coef_loss   | -30.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 30       |
# |    time_elapsed    | 131      |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -82.3    |
# |    critic_loss     | 2.26     |
# |    ent_coef        | 0.318    |
# |    ent_coef_loss   | -33.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 30       |
# |    time_elapsed    | 144      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 1.84     |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | -36.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 30       |
# |    time_elapsed    | 156      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -81.4    |
# |    critic_loss     | 2.42     |
# |    ent_coef        | 0.252    |
# |    ent_coef_loss   | -39.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -245     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 30       |
# |    time_elapsed    | 169      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -79.6    |
# |    critic_loss     | 1.7      |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -41.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -241     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 30       |
# |    time_elapsed    | 182      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -78      |
# |    critic_loss     | 1.79     |
# |    ent_coef        | 0.2      |
# |    ent_coef_loss   | -45.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -239     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 30       |
# |    time_elapsed    | 195      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -75.8    |
# |    critic_loss     | 1.52     |
# |    ent_coef        | 0.178    |
# |    ent_coef_loss   | -45.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -236     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 30       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -73.7    |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.159    |
# |    ent_coef_loss   | -49.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 30       |
# |    time_elapsed    | 220      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -70.6    |
# |    critic_loss     | 1.84     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -52.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 30       |
# |    time_elapsed    | 233      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -67.4    |
# |    critic_loss     | 1.72     |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -51.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 30       |
# |    time_elapsed    | 246      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -64.4    |
# |    critic_loss     | 1.72     |
# |    ent_coef        | 0.113    |
# |    ent_coef_loss   | -45.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -241     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 30       |
# |    time_elapsed    | 259      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -62.4    |
# |    critic_loss     | 2.1      |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -44      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -239     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 30       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -60      |
# |    critic_loss     | 1.42     |
# |    ent_coef        | 0.0947   |
# |    ent_coef_loss   | -32.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -238     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 30       |
# |    time_elapsed    | 285      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 1.32     |
# |    ent_coef        | 0.0875   |
# |    ent_coef_loss   | -30.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -236     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 30       |
# |    time_elapsed    | 298      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -54.1    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.0788   |
# |    ent_coef_loss   | -47.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -233     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 30       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -50.8    |
# |    critic_loss     | 1.35     |
# |    ent_coef        | 0.0699   |
# |    ent_coef_loss   | -50.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -231     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 30       |
# |    time_elapsed    | 323      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -48      |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0622   |
# |    ent_coef_loss   | -47.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -227     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 30       |
# |    time_elapsed    | 336      |
# |    total_timesteps | 10400    |
# | train/             |          |
# |    actor_loss      | -45.2    |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | -39.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -226     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 30       |
# |    time_elapsed    | 349      |
# |    total_timesteps | 10800    |
# | train/             |          |
# |    actor_loss      | -42.6    |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.0507   |
# |    ent_coef_loss   | -33.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 10699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -225     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 30       |
# |    time_elapsed    | 361      |
# |    total_timesteps | 11200    |
# | train/             |          |
# |    actor_loss      | -40.7    |
# |    critic_loss     | 1.66     |
# |    ent_coef        | 0.0469   |
# |    ent_coef_loss   | -25      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -223     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 30       |
# |    time_elapsed    | 374      |
# |    total_timesteps | 11600    |
# | train/             |          |
# |    actor_loss      | -38.6    |
# |    critic_loss     | 1.63     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | -20.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 30       |
# |    time_elapsed    | 387      |
# |    total_timesteps | 12000    |
# | train/             |          |
# |    actor_loss      | -35.5    |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0416   |
# |    ent_coef_loss   | -21.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 11899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -220     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 30       |
# |    time_elapsed    | 400      |
# |    total_timesteps | 12400    |
# | train/             |          |
# |    actor_loss      | -32.7    |
# |    critic_loss     | 1.5      |
# |    ent_coef        | 0.0387   |
# |    ent_coef_loss   | -25.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -218     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 30       |
# |    time_elapsed    | 412      |
# |    total_timesteps | 12800    |
# | train/             |          |
# |    actor_loss      | -31.2    |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0341   |
# |    ent_coef_loss   | -31.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 12699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 31       |
# |    time_elapsed    | 425      |
# |    total_timesteps | 13200    |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.0306   |
# |    ent_coef_loss   | -22.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -216     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 31       |
# |    time_elapsed    | 438      |
# |    total_timesteps | 13600    |
# | train/             |          |
# |    actor_loss      | -26.9    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.0281   |
# |    ent_coef_loss   | -17.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -214     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 31       |
# |    time_elapsed    | 450      |
# |    total_timesteps | 14000    |
# | train/             |          |
# |    actor_loss      | -24.6    |
# |    critic_loss     | 1.2      |
# |    ent_coef        | 0.026    |
# |    ent_coef_loss   | -24.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 13899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -211     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 31       |
# |    time_elapsed    | 463      |
# |    total_timesteps | 14400    |
# | train/             |          |
# |    actor_loss      | -22.9    |
# |    critic_loss     | 0.978    |
# |    ent_coef        | 0.0243   |
# |    ent_coef_loss   | -14.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -212     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 31       |
# |    time_elapsed    | 476      |
# |    total_timesteps | 14800    |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.0235   |
# |    ent_coef_loss   | -7.49    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 14699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -209     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 31       |
# |    time_elapsed    | 489      |
# |    total_timesteps | 15200    |
# | train/             |          |
# |    actor_loss      | -20.6    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.0235   |
# |    ent_coef_loss   | 3.91     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 31       |
# |    time_elapsed    | 502      |
# |    total_timesteps | 15600    |
# | train/             |          |
# |    actor_loss      | -19.5    |
# |    critic_loss     | 1.33     |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -3.39    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -208     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 31       |
# |    time_elapsed    | 514      |
# |    total_timesteps | 16000    |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 0.983    |
# |    ent_coef        | 0.0235   |
# |    ent_coef_loss   | -5.73    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 15899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -207     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 31       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 16400    |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0228   |
# |    ent_coef_loss   | -3.12    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -205     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 31       |
# |    time_elapsed    | 540      |
# |    total_timesteps | 16800    |
# | train/             |          |
# |    actor_loss      | -14.5    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.0218   |
# |    ent_coef_loss   | -3.98    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 16699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -203     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 31       |
# |    time_elapsed    | 553      |
# |    total_timesteps | 17200    |
# | train/             |          |
# |    actor_loss      | -12.8    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.0213   |
# |    ent_coef_loss   | -6.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -198     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 31       |
# |    time_elapsed    | 565      |
# |    total_timesteps | 17600    |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 31       |
# |    time_elapsed    | 578      |
# |    total_timesteps | 18000    |
# | train/             |          |
# |    actor_loss      | -9.22    |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -3.81    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 17899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 31       |
# |    time_elapsed    | 591      |
# |    total_timesteps | 18400    |
# | train/             |          |
# |    actor_loss      | -7.56    |
# |    critic_loss     | 0.875    |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 31       |
# |    time_elapsed    | 604      |
# |    total_timesteps | 18800    |
# | train/             |          |
# |    actor_loss      | -6.13    |
# |    critic_loss     | 0.818    |
# |    ent_coef        | 0.0168   |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 18699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 31       |
# |    time_elapsed    | 616      |
# |    total_timesteps | 19200    |
# | train/             |          |
# |    actor_loss      | -4.91    |
# |    critic_loss     | 0.846    |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 31       |
# |    time_elapsed    | 629      |
# |    total_timesteps | 19600    |
# | train/             |          |
# |    actor_loss      | -3.91    |
# |    critic_loss     | 0.886    |
# |    ent_coef        | 0.0165   |
# |    ent_coef_loss   | 4.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 31       |
# |    time_elapsed    | 642      |
# |    total_timesteps | 20000    |
# | train/             |          |
# |    actor_loss      | -2.82    |
# |    critic_loss     | 1.02     |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 3.59     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 19899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 31       |
# |    time_elapsed    | 656      |
# |    total_timesteps | 20400    |
# | train/             |          |
# |    actor_loss      | -1.09    |
# |    critic_loss     | 1.31     |
# |    ent_coef        | 0.0159   |
# |    ent_coef_loss   | -2.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 30       |
# |    time_elapsed    | 672      |
# |    total_timesteps | 20800    |
# | train/             |          |
# |    actor_loss      | -0.402   |
# |    critic_loss     | 1.09     |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | 0.247    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 20699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 30       |
# |    time_elapsed    | 687      |
# |    total_timesteps | 21200    |
# | train/             |          |
# |    actor_loss      | 1.21     |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | 0.481    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 30       |
# |    time_elapsed    | 702      |
# |    total_timesteps | 21600    |
# | train/             |          |
# |    actor_loss      | 1.88     |
# |    critic_loss     | 0.839    |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | 3.07     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 30       |
# |    time_elapsed    | 717      |
# |    total_timesteps | 22000    |
# | train/             |          |
# |    actor_loss      | 3.72     |
# |    critic_loss     | 0.918    |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | 2.18     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 21899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 30       |
# |    time_elapsed    | 731      |
# |    total_timesteps | 22400    |
# | train/             |          |
# |    actor_loss      | 4.4      |
# |    critic_loss     | 1.09     |
# |    ent_coef        | 0.0158   |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 30       |
# |    time_elapsed    | 745      |
# |    total_timesteps | 22800    |
# | train/             |          |
# |    actor_loss      | 6.45     |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.0154   |
# |    ent_coef_loss   | 2.67     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 22699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 30       |
# |    time_elapsed    | 763      |
# |    total_timesteps | 23200    |
# | train/             |          |
# |    actor_loss      | 7.49     |
# |    critic_loss     | 0.988    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | 7.37     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 30       |
# |    time_elapsed    | 779      |
# |    total_timesteps | 23600    |
# | train/             |          |
# |    actor_loss      | 9.37     |
# |    critic_loss     | 0.949    |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -1       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 30       |
# |    time_elapsed    | 795      |
# |    total_timesteps | 24000    |
# | train/             |          |
# |    actor_loss      | 10.2     |
# |    critic_loss     | 1.02     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | 3.11     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 23899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 30       |
# |    time_elapsed    | 810      |
# |    total_timesteps | 24400    |
# | train/             |          |
# |    actor_loss      | 10.2     |
# |    critic_loss     | 0.833    |
# |    ent_coef        | 0.02     |
# |    ent_coef_loss   | 0.871    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 30       |
# |    time_elapsed    | 826      |
# |    total_timesteps | 24800    |
# | train/             |          |
# |    actor_loss      | 10.9     |
# |    critic_loss     | 0.835    |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | 2.73     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 24699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 29       |
# |    time_elapsed    | 841      |
# |    total_timesteps | 25200    |
# | train/             |          |
# |    actor_loss      | 11.9     |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 29       |
# |    time_elapsed    | 857      |
# |    total_timesteps | 25600    |
# | train/             |          |
# |    actor_loss      | 13.3     |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -2.57    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 29       |
# |    time_elapsed    | 872      |
# |    total_timesteps | 26000    |
# | train/             |          |
# |    actor_loss      | 14.3     |
# |    critic_loss     | 0.94     |
# |    ent_coef        | 0.0184   |
# |    ent_coef_loss   | 3.48     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 25899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 29       |
# |    time_elapsed    | 888      |
# |    total_timesteps | 26400    |
# | train/             |          |
# |    actor_loss      | 15.1     |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | 3.5      |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 29       |
# |    time_elapsed    | 904      |
# |    total_timesteps | 26800    |
# | train/             |          |
# |    actor_loss      | 16.2     |
# |    critic_loss     | 0.986    |
# |    ent_coef        | 0.0176   |
# |    ent_coef_loss   | 2.06     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 26699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 29       |
# |    time_elapsed    | 919      |
# |    total_timesteps | 27200    |
# | train/             |          |
# |    actor_loss      | 17.2     |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | -5.43    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 29       |
# |    time_elapsed    | 935      |
# |    total_timesteps | 27600    |
# | train/             |          |
# |    actor_loss      | 17.8     |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -1.87    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 29       |
# |    time_elapsed    | 950      |
# |    total_timesteps | 28000    |
# | train/             |          |
# |    actor_loss      | 18.1     |
# |    critic_loss     | 1.16     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | -5.14    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 27899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 29       |
# |    time_elapsed    | 966      |
# |    total_timesteps | 28400    |
# | train/             |          |
# |    actor_loss      | 19.1     |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -4.63    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 29       |
# |    time_elapsed    | 982      |
# |    total_timesteps | 28800    |
# | train/             |          |
# |    actor_loss      | 19.7     |
# |    critic_loss     | 0.976    |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -4.61    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 28699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 29       |
# |    time_elapsed    | 997      |
# |    total_timesteps | 29200    |
# | train/             |          |
# |    actor_loss      | 21       |
# |    critic_loss     | 1.06     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 0.777    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 29       |
# |    time_elapsed    | 1013     |
# |    total_timesteps | 29600    |
# | train/             |          |
# |    actor_loss      | 21.5     |
# |    critic_loss     | 1.44     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.307    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 29       |
# |    time_elapsed    | 1028     |
# |    total_timesteps | 30000    |
# | train/             |          |
# |    actor_loss      | 22.1     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 29899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 29       |
# |    time_elapsed    | 1044     |
# |    total_timesteps | 30400    |
# | train/             |          |
# |    actor_loss      | 23.8     |
# |    critic_loss     | 1.2      |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | 1.51     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 29       |
# |    time_elapsed    | 1060     |
# |    total_timesteps | 30800    |
# | train/             |          |
# |    actor_loss      | 23.6     |
# |    critic_loss     | 0.92     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 30699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 29       |
# |    time_elapsed    | 1075     |
# |    total_timesteps | 31200    |
# | train/             |          |
# |    actor_loss      | 23.7     |
# |    critic_loss     | 0.766    |
# |    ent_coef        | 0.0222   |
# |    ent_coef_loss   | 2.76     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 28       |
# |    time_elapsed    | 1091     |
# |    total_timesteps | 31600    |
# | train/             |          |
# |    actor_loss      | 24.4     |
# |    critic_loss     | 0.987    |
# |    ent_coef        | 0.022    |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 28       |
# |    time_elapsed    | 1106     |
# |    total_timesteps | 32000    |
# | train/             |          |
# |    actor_loss      | 23.8     |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.0219   |
# |    ent_coef_loss   | 3.45     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 31899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 28       |
# |    time_elapsed    | 1122     |
# |    total_timesteps | 32400    |
# | train/             |          |
# |    actor_loss      | 23.6     |
# |    critic_loss     | 0.993    |
# |    ent_coef        | 0.022    |
# |    ent_coef_loss   | 0.857    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 28       |
# |    time_elapsed    | 1137     |
# |    total_timesteps | 32800    |
# | train/             |          |
# |    actor_loss      | 23.7     |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | 1.67     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 32699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 28       |
# |    time_elapsed    | 1153     |
# |    total_timesteps | 33200    |
# | train/             |          |
# |    actor_loss      | 24.5     |
# |    critic_loss     | 0.933    |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | -2.28    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 33099    |
# ...
# |    fps             | 28       |
# |    time_elapsed    | 1391     |
# |    total_timesteps | 39200    |
# | train/             |          |
# |    actor_loss      | 34.8     |
# |    critic_loss     | 0.91     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -199     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 28       |
# |    time_elapsed    | 1407     |
# |    total_timesteps | 39600    |
# | train/             |          |
# |    actor_loss      | 35.9     |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | 4.64     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 28       |
# |    time_elapsed    | 1422     |
# |    total_timesteps | 40000    |
# | train/             |          |
# |    actor_loss      | 36.8     |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 4.24     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 39899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 28       |
# |    time_elapsed    | 1438     |
# |    total_timesteps | 40400    |
# | train/             |          |
# |    actor_loss      | 36.5     |
# |    critic_loss     | 0.896    |
# |    ent_coef        | 0.0221   |
# |    ent_coef_loss   | -3.42    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 28       |
# |    time_elapsed    | 1454     |
# |    total_timesteps | 40800    |
# | train/             |          |
# |    actor_loss      | 37.1     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | 1.89     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 40699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 28       |
# |    time_elapsed    | 1470     |
# |    total_timesteps | 41200    |
# | train/             |          |
# |    actor_loss      | 38.6     |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | -3.58    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -203     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 28       |
# |    time_elapsed    | 1485     |
# |    total_timesteps | 41600    |
# | train/             |          |
# |    actor_loss      | 38.9     |
# |    critic_loss     | 1.24     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -202     |
# | time/              |          |
# |    episodes        | 420      |
# |    fps             | 27       |
# |    time_elapsed    | 1501     |
# |    total_timesteps | 42000    |
# | train/             |          |
# |    actor_loss      | 40       |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -1.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 41899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    episodes        | 424      |
# |    fps             | 27       |
# |    time_elapsed    | 1516     |
# |    total_timesteps | 42400    |
# | train/             |          |
# |    actor_loss      | 40.9     |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | 1.71     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -202     |
# | time/              |          |
# |    episodes        | 428      |
# |    fps             | 27       |
# |    time_elapsed    | 1531     |
# |    total_timesteps | 42800    |
# | train/             |          |
# |    actor_loss      | 41.9     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0211   |
# |    ent_coef_loss   | -4.94    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 42699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    episodes        | 432      |
# |    fps             | 27       |
# |    time_elapsed    | 1547     |
# |    total_timesteps | 43200    |
# | train/             |          |
# |    actor_loss      | 42.2     |
# |    critic_loss     | 1.55     |
# |    ent_coef        | 0.0208   |
# |    ent_coef_loss   | -1.71    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 436      |
# |    fps             | 27       |
# |    time_elapsed    | 1564     |
# |    total_timesteps | 43600    |
# | train/             |          |
# |    actor_loss      | 43.2     |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 4.77     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -197     |
# | time/              |          |
# |    episodes        | 440      |
# |    fps             | 27       |
# |    time_elapsed    | 1580     |
# |    total_timesteps | 44000    |
# | train/             |          |
# |    actor_loss      | 44.2     |
# |    critic_loss     | 1.12     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 6.51     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 43899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -196     |
# | time/              |          |
# |    episodes        | 444      |
# |    fps             | 27       |
# |    time_elapsed    | 1596     |
# |    total_timesteps | 44400    |
# | train/             |          |
# |    actor_loss      | 44.7     |
# |    critic_loss     | 1.1      |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 0.104    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -195     |
# | time/              |          |
# |    episodes        | 448      |
# |    fps             | 27       |
# |    time_elapsed    | 1612     |
# |    total_timesteps | 44800    |
# | train/             |          |
# |    actor_loss      | 45.3     |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -1.24    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 44699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -194     |
# | time/              |          |
# |    episodes        | 452      |
# |    fps             | 27       |
# |    time_elapsed    | 1628     |
# |    total_timesteps | 45200    |
# | train/             |          |
# |    actor_loss      | 45       |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | 3.14     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 456      |
# |    fps             | 27       |
# |    time_elapsed    | 1645     |
# |    total_timesteps | 45600    |
# | train/             |          |
# |    actor_loss      | 45.5     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.0216   |
# |    ent_coef_loss   | 3.48     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -193     |
# | time/              |          |
# |    episodes        | 460      |
# |    fps             | 27       |
# |    time_elapsed    | 1661     |
# |    total_timesteps | 46000    |
# | train/             |          |
# |    actor_loss      | 45.7     |
# |    critic_loss     | 1.27     |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | 2.28     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 45899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -189     |
# | time/              |          |
# |    episodes        | 464      |
# |    fps             | 27       |
# |    time_elapsed    | 1678     |
# |    total_timesteps | 46400    |
# | train/             |          |
# |    actor_loss      | 45.9     |
# |    critic_loss     | 1.22     |
# |    ent_coef        | 0.0237   |
# |    ent_coef_loss   | -0.0616  |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 468      |
# |    fps             | 27       |
# |    time_elapsed    | 1695     |
# |    total_timesteps | 46800    |
# | train/             |          |
# |    actor_loss      | 46.3     |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.023    |
# |    ent_coef_loss   | -5.47    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 46699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -191     |
# | time/              |          |
# |    episodes        | 472      |
# |    fps             | 27       |
# |    time_elapsed    | 1711     |
# |    total_timesteps | 47200    |
# | train/             |          |
# |    actor_loss      | 46.9     |
# |    critic_loss     | 1.2      |
# |    ent_coef        | 0.0233   |
# |    ent_coef_loss   | -2       |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -192     |
# | time/              |          |
# |    episodes        | 476      |
# |    fps             | 27       |
# |    time_elapsed    | 1727     |
# |    total_timesteps | 47600    |
# | train/             |          |
# |    actor_loss      | 47.5     |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0233   |
# |    ent_coef_loss   | 0.158    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -190     |
# | time/              |          |
# |    episodes        | 480      |
# |    fps             | 27       |
# |    time_elapsed    | 1742     |
# |    total_timesteps | 48000    |
# | train/             |          |
# |    actor_loss      | 48.3     |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | -4.34    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 47899    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -187     |
# | time/              |          |
# |    episodes        | 484      |
# |    fps             | 27       |
# |    time_elapsed    | 1758     |
# |    total_timesteps | 48400    |
# | train/             |          |
# |    actor_loss      | 48.5     |
# |    critic_loss     | 0.957    |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | 0.976    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -185     |
# | time/              |          |
# |    episodes        | 488      |
# |    fps             | 27       |
# |    time_elapsed    | 1774     |
# |    total_timesteps | 48800    |
# | train/             |          |
# |    actor_loss      | 49.6     |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.0217   |
# |    ent_coef_loss   | -2.76    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 48699    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -186     |
# | time/              |          |
# |    episodes        | 492      |
# |    fps             | 27       |
# |    time_elapsed    | 1790     |
# |    total_timesteps | 49200    |
# | train/             |          |
# |    actor_loss      | 50.6     |
# |    critic_loss     | 1.18     |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49099    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -187     |
# | time/              |          |
# |    episodes        | 496      |
# |    fps             | 27       |
# |    time_elapsed    | 1805     |
# |    total_timesteps | 49600    |
# | train/             |          |
# |    actor_loss      | 50.2     |
# |    critic_loss     | 0.887    |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | 2.88     |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49499    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -187     |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 27       |
# |    time_elapsed    | 1821     |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | 51.2     |
# |    critic_loss     | 0.993    |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | 0.0327   |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 49899    |
# ---------------------------------

# %%
model = SAC.load("dual_arm_model_obs34", env=env)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
def evaluate_policy_once(env, model, steps=50):
    obs, _ = env.reset()
    rewards = []
    collisions = []

    for _ in range(steps):
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)

        rewards.append(reward)
        collisions.append(info["Collisions"])

        if terminated or truncated:
            break

    print("Steps run:", len(rewards))
    print("Average reward:", sum(rewards) / len(rewards))
    print("Total collision penalty:", sum(collisions))
    print("Collision steps:", sum(1 for c in collisions if c > 0))

# %%
def evaluate_random_once(env, steps=50):
    obs, _ = env.reset()
    rewards = []
    collisions = []

    for _ in range(steps):
        action = env.action_space.sample()
        obs, reward, terminated, truncated, info = env.step(action)

        rewards.append(reward)
        collisions.append(info["Collisions"])

        if terminated or truncated:
            break

    print("RANDOM POLICY")
    print("Steps run:", len(rewards))
    print("Average reward:", sum(rewards) / len(rewards))
    print("Total collision penalty:", sum(collisions))
    print("Collision steps:", sum(1 for c in collisions if c > 0))

# %%
import matplotlib.pyplot as plt

# %%
labels = ["Random", "Trained"]
avg_rewards = [-3.50, -2.17]
collisions = [14, 3]
print("data ok")
# Out:
# data ok

# %%
evaluate_policy_once(env, model, steps=50)
# Out:
# Steps run: 50
# Average reward: -1.9034696438259346
# Total collision penalty: 0
# Collision steps: 0

# %%
obs, _ = env.reset()

for _ in range(50):
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)

    print("Reward:", reward)
    print("Collisions:", info["Collisions"])
# Out:
# Reward: -6.749591752276078
# Collisions: 1
# Reward: -6.954237741543039
# Collisions: 1
# Reward: -1.906889177424266
# Collisions: 0
# Reward: -1.8905652297871227
# Collisions: 0
# Reward: -1.7468291356442187
# Collisions: 0
# Reward: -1.8146008767026547
# Collisions: 0
# Reward: -1.9168340762790574
# Collisions: 0
# Reward: -2.2935709007027065
# Collisions: 0
# Reward: -2.3636539747974985
# Collisions: 0
# Reward: -2.042872064917537
# Collisions: 0
# Reward: -11.807794024961622
# Collisions: 2
# Reward: -1.8758067393135514
# Collisions: 0
# Reward: -6.849701470482351
# Collisions: 1
# Reward: -1.8063264152617204
# Collisions: 0
# Reward: -2.2632478960062903
# Collisions: 0
# Reward: -1.8974582228661236
# Collisions: 0
# Reward: -1.849137806844432
# Collisions: 0
# Reward: -1.786532294099398
# Collisions: 0
# Reward: -1.8179762152606178
# Collisions: 0
# Reward: -6.725918761594234
# Collisions: 1
# Reward: -1.6940186947691938
# Collisions: 0
# Reward: -1.8258522322944453
# Collisions: 0
# Reward: -1.819672067545797
# Collisions: 0
# Reward: -1.700729002588146
# Collisions: 0
# Reward: -1.6450460028145808
# Collisions: 0
# Reward: -1.623279676333091
# Collisions: 0
# Reward: -1.747921411308611
# Collisions: 0
# Reward: -1.8743657888082976
# Collisions: 0
# Reward: -1.9659710181743963
# Collisions: 0
# Reward: -1.8247373023352211
# Collisions: 0
# Reward: -1.7435441492361767
# Collisions: 0
# Reward: -1.8449356993350836
# Collisions: 0
# Reward: -1.7313980824695125
# Collisions: 0
# Reward: -1.8631073351140857
# Collisions: 0
# Reward: -1.656950977120503
# Collisions: 0
# Reward: -1.643138431055198
# Collisions: 0
# Reward: -1.7559474492781215
# Collisions: 0
# Reward: -1.6339247879743075
# Collisions: 0
# Reward: -1.4737135535875376
# Collisions: 0
# Reward: -1.5361695392781811
# Collisions: 0
# Reward: -1.6604639854360224
# Collisions: 0
# Reward: -1.9045341001483829
# Collisions: 0
# Reward: -1.9660848487099485
# Collisions: 0
# Reward: -1.9220498333584424
# Collisions: 0
# Reward: -1.8517741493980338
# Collisions: 0
# Reward: -1.9726952106033755
# Collisions: 0
# Reward: -1.7759948134542338
# Collisions: 0
# Reward: -1.5755803580860315
# Collisions: 0
# Reward: -1.48905434796418
# Collisions: 0
# Reward: -1.491924463188449
# Collisions: 0

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\kdsaj\anaconda3\envs\ultrasound310\python.exe

# %%
from stable_baselines3.common.env_checker import check_env

# %%
# checking the environment 
# If the environment don't follow the interface, an error will be thrown
check_env(env, warn=True)

# %%
# training Agent 
from stable_baselines3 import SAC
#import ipywidgets as widgets
#from IPython.display import display

# Instantiate the callback
#plotting_callback = CustomCallback()

model = SAC("MlpPolicy", env, verbose=1)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=500)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -345     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 37       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -27.2    |
# |    critic_loss     | 4.46     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------

# %%
model.save("dual_arm_model_obs34")

# %%
import time

obs, _ = env.reset()

for _ in range(200):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    time.sleep(0.05)

    if terminated or truncated:
        obs, _ = env.reset()

# %%
model = SAC("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=500)
model.save("dual_arm_model_obs34")
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -332     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 37       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -27.6    |
# |    critic_loss     | 3.37     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -2.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------

# %%
#import time

#obs, _ = env.reset()

#for _ in range(200):
    #action, _ = model.predict(obs)
    #obs, reward, terminated, truncated, info = env.step(action)
    #time.sleep(0.05)

    #if terminated or truncated:
        #obs, _ = env.reset()

# %%
#from stable_baselines3 import SAC

#model = SAC("MlpPolicy", env, verbose=1).learn(total_timesteps=10000)
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -361     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 46       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 400      |
# | train/             |          |
# |    actor_loss      | -27.7    |
# |    critic_loss     | 5.02     |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -2.95    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 299      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -319     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 42       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 800      |
# | train/             |          |
# |    actor_loss      | -38.5    |
# |    critic_loss     | 2.14     |
# |    ent_coef        | 0.812    |
# |    ent_coef_loss   | -6.79    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 699      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -288     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 41       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 1200     |
# | train/             |          |
# |    actor_loss      | -49.4    |
# |    critic_loss     | 2.56     |
# |    ent_coef        | 0.722    |
# |    ent_coef_loss   | -10.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -283     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 41       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 1600     |
# | train/             |          |
# |    actor_loss      | -58.5    |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.642    |
# |    ent_coef_loss   | -13.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -276     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 41       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 2000     |
# | train/             |          |
# |    actor_loss      | -65.5    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.571    |
# |    ent_coef_loss   | -17.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 1899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -267     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 41       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | -71.3    |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.508    |
# |    ent_coef_loss   | -20.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -261     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 41       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 2800     |
# | train/             |          |
# |    actor_loss      | -76.1    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.452    |
# |    ent_coef_loss   | -24.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 2699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -254     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 40       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 3200     |
# | train/             |          |
# |    actor_loss      | -79.4    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.402    |
# |    ent_coef_loss   | -27.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -248     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 40       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 3600     |
# | train/             |          |
# |    actor_loss      | -80.8    |
# |    critic_loss     | 1.81     |
# |    ent_coef        | 0.358    |
# |    ent_coef_loss   | -30.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -247     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 40       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 4000     |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.318    |
# |    ent_coef_loss   | -33.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 3899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -245     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 40       |
# |    time_elapsed    | 107      |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -82.4    |
# |    critic_loss     | 1.62     |
# |    ent_coef        | 0.283    |
# |    ent_coef_loss   | -37.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -253     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 40       |
# |    time_elapsed    | 117      |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | -82      |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.252    |
# |    ent_coef_loss   | -37.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 4699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -250     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 40       |
# |    time_elapsed    | 127      |
# |    total_timesteps | 5200     |
# | train/             |          |
# |    actor_loss      | -80.8    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.225    |
# |    ent_coef_loss   | -42.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -247     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 40       |
# |    time_elapsed    | 137      |
# |    total_timesteps | 5600     |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.2      |
# |    ent_coef_loss   | -45.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -244     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 40       |
# |    time_elapsed    | 147      |
# |    total_timesteps | 6000     |
# | train/             |          |
# |    actor_loss      | -76.9    |
# |    critic_loss     | 1.58     |
# |    ent_coef        | 0.178    |
# |    ent_coef_loss   | -48.3    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 5899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 40       |
# |    time_elapsed    | 159      |
# |    total_timesteps | 6400     |
# | train/             |          |
# |    actor_loss      | -74.2    |
# |    critic_loss     | 1.16     |
# |    ent_coef        | 0.158    |
# |    ent_coef_loss   | -50.9    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 39       |
# |    time_elapsed    | 172      |
# |    total_timesteps | 6800     |
# | train/             |          |
# |    actor_loss      | -71.9    |
# |    critic_loss     | 1.52     |
# |    ent_coef        | 0.141    |
# |    ent_coef_loss   | -51.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 6699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 38       |
# |    time_elapsed    | 185      |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | -69.4    |
# |    critic_loss     | 1.38     |
# |    ent_coef        | 0.126    |
# |    ent_coef_loss   | -53.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -243     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 38       |
# |    time_elapsed    | 198      |
# |    total_timesteps | 7600     |
# | train/             |          |
# |    actor_loss      | -66.8    |
# |    critic_loss     | 2.46     |
# |    ent_coef        | 0.112    |
# |    ent_coef_loss   | -55.8    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -240     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 38       |
# |    time_elapsed    | 210      |
# |    total_timesteps | 8000     |
# | train/             |          |
# |    actor_loss      | -63.3    |
# |    critic_loss     | 1.38     |
# |    ent_coef        | 0.101    |
# |    ent_coef_loss   | -55.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 7899     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 37       |
# |    time_elapsed    | 223      |
# |    total_timesteps | 8400     |
# | train/             |          |
# |    actor_loss      | -60.2    |
# |    critic_loss     | 1.33     |
# |    ent_coef        | 0.0901   |
# |    ent_coef_loss   | -52.7    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8299     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 37       |
# |    time_elapsed    | 235      |
# |    total_timesteps | 8800     |
# | train/             |          |
# |    actor_loss      | -57.1    |
# |    critic_loss     | 1.48     |
# |    ent_coef        | 0.0812   |
# |    ent_coef_loss   | -49.5    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8699     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -235     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 37       |
# |    time_elapsed    | 247      |
# |    total_timesteps | 9200     |
# | train/             |          |
# |    actor_loss      | -54      |
# |    critic_loss     | 1.49     |
# |    ent_coef        | 0.074    |
# |    ent_coef_loss   | -44.2    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9099     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -234     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 36       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | -52      |
# |    critic_loss     | 1.74     |
# |    ent_coef        | 0.0676   |
# |    ent_coef_loss   | -35.1    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9499     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -237     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 36       |
# |    time_elapsed    | 272      |
# |    total_timesteps | 10000    |
# | train/             |          |
# |    actor_loss      | -50.2    |
# |    critic_loss     | 1.5      |
# |    ent_coef        | 0.0627   |
# |    ent_coef_loss   | -31.4    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 9899     |
# ---------------------------------

# %%
from stable_baselines3.common.monitor import Monitor

env = Monitor(RightArmRobot(render_mode=None))

# %%
from stable_baselines3 import SAC

model = SAC.load("dual_arm_model_obs34", env=env)
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
obs, _ = env.reset()

rewards = []
collisions = []

for _ in range(50):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)

    rewards.append(reward)
    collisions.append(info["Collisions"])

    if terminated or truncated:
        break

print("Average reward:", sum(rewards)/len(rewards))
print("Total collisions:", sum(collisions))
# Out:
# Average reward: -1.8689105582065642
# Total collisions: 0

# %%
obs, _ = env.reset()

rewards = []
collisions = []

for _ in range(50):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)

    rewards.append(reward)
    collisions.append(info["Collisions"])

    if terminated or truncated:
        break

print("Average reward:", sum(rewards)/len(rewards))
print("Total collisions:", sum(collisions))
# Out:
# Average reward: -3.354917121477514
# Total collisions: 17
