# %%
import os
print(os.getcwd())
# !ls
# Out:
# /cephfs/volumes/hpc_data_usr/k24021136/79e7a54a-c7ee-4c01-9056-d9f30f39602d/Ultrasound-project-Git/One_arm_Git
#  Clinical_R1_Maternal_Curriculum_Final
#  Clinical_R1_Maternal_Curriculum_Final.zip
# 'Housden created STL and URDF 5'
# 'JRun (3).ipynb'
#  JRun.ipynb
#  JRun_deterministic_evaluation.ipynb
#  JRunbaseline100k.ipynb
#  JRunbaseline20k.ipynb
#  Post_processing_j_R1.m
#  Ultrasound_Training.ipynb
#  evaluation_results
#  models
#  progressPoseNew_100k.ipynb
#  progressPoseRot2_100k.ipynb
#  progressPose_100k.ipynb
#  progressReward20k.ipynb
#  progressStepPenalty_20k.ipynb
#  progressnew_100k-.ipynb
#  results
# 'results zhiqian'
#  vec_normalize_stats_maternal_curriculum.pkl

# %%
# !pip -q install pybullet gymnasium stable-baselines3

# %%
# functions nessersary
import numpy as np
import math

# Converts Euler angles ([rx, ry, rz] in deg) to a 3x3 rotation matrix
def EulerToRMat(Euler):

    sx = math.sin(Euler[0]);
    sy = math.sin(Euler[1]);
    sz = math.sin(Euler[2]);
    cx = math.cos(Euler[0]);
    cy = math.cos(Euler[1]);
    cz = math.cos(Euler[2]);

    RMat = np.eye(3);
    RMat[0,0] = cy*cz;
    RMat[0,1] = sx*sy*cz-cx*sz;
    RMat[0,2] = cx*sy*cz+sx*sz;
    RMat[1,0] = cy*sz;
    RMat[1,1] = sx*sy*sz+cx*cz;
    RMat[1,2] = cx*sy*sz-sx*cz;
    RMat[2,0] = -sy;
    RMat[2,1] = sx*cy;
    RMat[2,2] = cx*cy;

    return RMat

# Converts a 3x3 rotation matrix to a quaternion
def RMatToQuat(RMat):

    quat = np.zeros((4,1));

    # abs is to avoid rounding errors in the sqrt - it shouldn't be negative anyway
    quat[0] = 0.5 * math.sqrt(abs(1 + RMat[0,0] + RMat[1,1] + RMat[2,2]));

    if (RMat[2,1] - RMat[1,2] > 0):
        quat[1] = 0.5 * math.sqrt(abs(1 + RMat[0,0] - RMat[1,1] - RMat[2,2]));
    else:
        quat[1] = -0.5 * math.sqrt(abs(1 + RMat[0,0] - RMat[1,1] - RMat[2,2]));


    if (RMat[0,2] - RMat[2,0] > 0):
        quat[2] = 0.5 * math.sqrt(abs(1 - RMat[0,0] + RMat[1,1] - RMat[2,2]));
    else:
        quat[2] = -0.5 * math.sqrt(abs(1 - RMat[0,0] + RMat[1,1] - RMat[2,2]));

    if (RMat[1,0] - RMat[0,1] > 0):
        quat[3] = 0.5 * math.sqrt(abs(1 - RMat[0,0] - RMat[1,1] + RMat[2,2]));
    else:
        quat[3] = -0.5 * math.sqrt(abs(1 - RMat[0,0] - RMat[1,1] + RMat[2,2]));

    return quat

# caclulating difference in Quaternions angles
def quatDiff(q1, q2):

    # Difference: qd = q2 * q1c (q1c = conjugate of q1 = inverse of q1)
    # qd = (w2 + i.x2 + j.y2 + k.z2)(w1 - i.x1 - j.y1 - k.z1)
    # qd = w1.w2 - i.x1.w2 - j.y1.w2 - k.z1.w2 + i.w1.x2 - i^2.x1.x2 - ij.y1.x2 - ik.z1.x2 + j.w1.y2 - ji.x1.y2 - j^2.y1.y2 - jk.z1.y2 + k.w1.z2 - ki.x1.z2 - kj.y1.z2 - k^2.z1.z2
    # qd(1) =  w1.w2 + x1.x2 + y1.y2 + z1.z2
    # qd(2) = -x1.w2 + w1.x2 - z1.y2 + y1.z2
    # qd(3) = -y1.w2 + z1.x2 + w1.y2 - x1.z2
    # qd(4) = -z1.w2 - y1.x2 + x1.y2 + w1.z2

    qd = np.zeros((4,1));
    qd[0] =  q1[0]*q2[0] + q1[1]*q2[1] + q1[2]*q2[2] + q1[3]*q2[3]
    qd[1] = -q1[1]*q2[0] + q1[0]*q2[1] - q1[3]*q2[2] + q1[2]*q2[3]
    qd[2] = -q1[2]*q2[0] + q1[3]*q2[1] + q1[0]*q2[2] - q1[1]*q2[3]
    qd[3] = -q1[3]*q2[0] - q1[2]*q2[1] + q1[1]*q2[2] + q1[0]*q2[3]

    a = 2 * np.arccos(np.float32(qd[0]))

    a = abs(a);

    return a, qd

# normalisation function between -1 and +1
def normalise(x, min_val, max_val):

    # equation for normalisation
    x_n = (2 * (x - min_val) / (max_val - min_val)) - 1

    return x_n

# %%
## creating an environment class (child class to gym.Env) for the Ultrasound Robot
import os
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import pybullet as p
import pybullet_utils.bullet_client as bullet_client
import random
import math
import matplotlib.pyplot as plt
import time

class RightArmRobot(gym.Env):
    """
    Custom Environment that follows gym interface.
    """

    # metadata for PyBullet simulation
    metadata = {"render_modes": ["human", "rgb_array"], "simulation_fps": 50}

    def __init__(self, render_mode="human"):

        # calls constructor of parent class gym.Env
        super(RightArmRobot, self).__init__()

        # setting up the render mode for visualisation
        self.render_mode = render_mode

        # initialise PyBullet client ID
        self._physics_client_id = -1

        # initialising the action space as continuous
        # action is angles of all 10 motorised joints
        self.action_space = spaces.Box(low=-1, high=1, shape=(10,), dtype=np.float32)

        # initialising the observation space as continuous
        self.observation_space = spaces.Box(low=-10, high=10, shape=(19,), dtype=np.float32)

        # tolerance for goal completion (position)
        self.pos_tol = 0.02

        # tolerance for goal completion (orientation)
        self.orient_tol = 0.2

        # initialising step number
        self.step_number = 0

        # initialising episode number
        self.episode_number = 0

        # initialise the max step number
        self.max_step_size = 300

        # reset function called to properly initialise the environment
        self.reset()

    def reset(self, seed=None, options=None):

        # re-initialisation of environment after truncation / termination / initialisation

        # reset step number
        self.step_number = 0

        # increase the episode number
        self.episode_number += 1

        # calls constructor of parent class gym.Env
        super().reset(seed=seed, options=options)

        # random number generator to provide new target position for the robot
        self.x_target = random.random() * (0.15 - -0.10)
        self.y_target = random.random() * (0.65 - 0.3) + 0.3
        self.z_target = random.random() * (0.35 - 0.15) + 0.15
        self.pos_target = np.array([self.x_target, self.y_target, self.z_target], dtype=np.float32)

        # new orientation target (in Euler angles)
        self.x_euler_t = random.random() * (-0.785398 - -2.35619)
        self.y_euler_t = random.random() * (0.785398 - -0.785398)
        self.z_euler_t = random.random() * (math.pi - -math.pi)
        self.euler_t = np.array([self.x_euler_t, self.y_euler_t, self.z_euler_t])

        # converting the target Euler angles into rotation matrix
        self.Mat_t = EulerToRMat(self.euler_t)

        # converting the target rotation matrix into quaternion
        self.Quat_t = RMatToQuat(self.Mat_t)

        # setup PyBullet client
        if self._physics_client_id < 0:
            if self.render_mode == "human":
                self._bullet_client = bullet_client.BulletClient(connection_mode=p.DIRECT)
            else:
                self._bullet_client = bullet_client.BulletClient()
            self._physics_client_id = self._bullet_client._client

        # setting up PyBullet simulation
        self._bullet_client.resetSimulation()
        self._bullet_client.setGravity(0, 0, -9.8)
        self._bullet_client.setTimeStep(1.0 / self.metadata["simulation_fps"])

        # load robot
        urdf_dir = os.path.join(os.getcwd(), "Housden created STL and URDF 5")
        self._bullet_client.setAdditionalSearchPath(urdf_dir)

        self.RightArmRobot = self._bullet_client.loadURDF(
            os.path.join(urdf_dir, "RightArm.urdf"),
            [0, 0, 0],
            useFixedBase=True
        )

        # check if loading of the robot was successful
        if self.RightArmRobot < 0:
            raise FileNotFoundError("Failed to load RightArm.urdf. Check the file path.")

        # check the number of joints
        self.num_joints = self._bullet_client.getNumJoints(self.RightArmRobot)

        # validate link index
        link_index = 9
        if link_index >= self.num_joints:
            raise IndexError(f"Invalid link index {link_index}. Max index is {self.num_joints - 1}.")

        # get link state
        link_state = self._bullet_client.getLinkState(self.RightArmRobot, link_index)
        if link_state is None:
            raise RuntimeError(f"Failed to get link state for link {link_index}.")

        # get the position of the final link of interest
        link_index = self.num_joints - 1
        link_state = self._bullet_client.getLinkState(self.RightArmRobot, link_index)

        # extracting the x y z position
        self.position = np.array(link_state[0], dtype=np.float32)

        # extracting the orientation as a quaternion
        self.orientation = np.array(link_state[1], dtype=np.float32)

        # calculating initial Euclidean distance from target
        self.Euclid_dist = float(math.dist(self.position, self.pos_target))

        # initialise previous Euclidean distance using the initial distance
        self.prev_Euclid_dist = self.Euclid_dist

        # calculating angular difference from target orientation
        self.Quaternion_diff = quatDiff(self.orientation, self.Quat_t)
        self.Quat_diff_angle = np.asarray(self.Quaternion_diff[0]).item()
        self.Quat_diff_Q = self.Quaternion_diff[1]

        # initialise previous quaternion angle difference
        self.prev_Quat_diff_angle = self.Quat_diff_angle

        # normalising target positions
        self.x_target_n = normalise(self.x_target, -0.10, 0.15)
        self.y_target_n = normalise(self.y_target, 0.3, 0.65)
        self.z_target_n = normalise(self.z_target, 0.15, 0.35)
        self.pos_target_n = np.array([self.x_target_n, self.y_target_n, self.z_target_n], dtype=np.float32)

        # normalising actual positions
        self.x_pos_n = normalise(self.position[0], -0.10, 0.15)
        self.y_pos_n = normalise(self.position[1], 0.3, 0.65)
        self.z_pos_n = normalise(self.position[2], 0.15, 0.35)
        self.pos_n = np.array([self.x_pos_n, self.y_pos_n, self.z_pos_n], dtype=np.float32)

        # observation is:
        # Euclidean distance + quaternion difference + target positions + current positions
        # + current orientation + target orientation
        self.observation = np.concatenate([
            np.array([self.Euclid_dist], dtype=np.float32),
            np.array([self.Quat_diff_Q], dtype=np.float32).flatten(),
            self.pos_target_n.flatten(),
            self.pos_n.flatten(),
            self.orientation.flatten(),
            self.Quat_t.flatten()
        ]).astype(np.float32)

        return self.observation, {}

    def step(self, action):

        # updating the step counter each step
        self.step_number += 1

        # initialise the scaled action variable
        scaled_action = action.copy()

        # scale action by pi
        for i in range(10):
            if i == 0:
                scaled_action[i] = action[i] / 4
            else:
                scaled_action[i] = action[i] * np.pi

        # applying dependent joint constraint
        scaled_action[2] = -scaled_action[1]

        # apply action to robot
        for i in range(10):
            self._bullet_client.setJointMotorControl2(
                self.RightArmRobot,
                i,
                p.POSITION_CONTROL,
                targetPosition=scaled_action[i]
            )

        # update simulation for a few steps
        for _ in range(3):
            self._bullet_client.stepSimulation()

        # get final link state
        link_state = self._bullet_client.getLinkState(self.RightArmRobot, self.num_joints - 1)

        # position and orientation
        self.position = np.array(link_state[0], dtype=np.float32)
        self.orientation = np.array(link_state[1], dtype=np.float32)

        # normalising actual positions
        self.x_pos_n = normalise(self.position[0], -0.10, 0.15)
        self.y_pos_n = normalise(self.position[1], 0.3, 0.65)
        self.z_pos_n = normalise(self.position[2], 0.15, 0.35)
        self.pos_n = np.array([self.x_pos_n, self.y_pos_n, self.z_pos_n], dtype=np.float32)

        # calculating the Euclidean distance
        self.Euclid_dist = float(math.dist(self.position, self.pos_target))

        # calculating the quaternion difference
        self.Quaternion_diff = quatDiff(self.orientation, self.Quat_t)
        self.Quat_diff_angle = np.asarray(self.Quaternion_diff[0]).item()
        self.Quat_diff_Q = self.Quaternion_diff[1]

        # observation
        self.observation = np.concatenate([
            np.array([self.Euclid_dist], dtype=np.float32),
            np.array([self.Quat_diff_Q], dtype=np.float32).flatten(),
            self.pos_target_n.flatten(),
            self.pos_n.flatten(),
            self.orientation.flatten(),
            self.Quat_t.flatten()
        ]).astype(np.float32)

        # new observation stored in variable obs
        obs = self.observation

        # normalising the Euclidean distance to 0-1
        self.Euclid_dist_n = float(np.clip(self.Euclid_dist / 0.7533, 0, 1))

        # baseline reward (position only)
        reward = float(-self.Euclid_dist_n)

        # position progress reward
        progress_pos = float(self.prev_Euclid_dist - self.Euclid_dist)
        reward += 5.0 * progress_pos

        # update previous values
        self.prev_Euclid_dist = self.Euclid_dist
        self.prev_Quat_diff_angle = self.Quat_diff_angle

        # convergence criteria
        if (self.Euclid_dist < self.pos_tol):
            reward += 100.0
            print("Terminated")
            print("Target position x: ", self.x_target)
            print("Target position y: ", self.y_target)
            print("Target position z: ", self.z_target)
            terminated = True
        else:
            terminated = False

        # truncation criteria
        if self.step_number < self.max_step_size:
            truncated = False
        else:
            truncated = True

        # make sure outputs are Python types
        reward = float(reward)
        terminated = bool(terminated)
        truncated = bool(truncated)

        # updating the info dictionary
        info = {
            "Truncated": truncated,
            "Terminated": terminated,
            "Observations": obs,
            "AngleDiff": self.Quat_diff_angle
        }

        # returning all step variables in a tuple
        return obs, reward, terminated, truncated, info
# Out:
# pybullet build time: Jan 29 2025 23:16:28

# %%
# defining the custom callback
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.evaluation import evaluate_policy
import numpy as np
import matplotlib.pyplot as plt
import json

class CustomCallback(BaseCallback):

    # initialisation of callback
    def __init__(self, run_name="progressnew_500k", total_timesteps=100000, verbose=0):
        super().__init__(verbose)
        self.run_name = run_name
        self.total_timesteps_target = total_timesteps

        # initialisation of variables
        self.timesteps = 0
        self.cum_rewards = 0.0
        self.episode_rewards = []
        self.number_of_episodes = 0
        self.terminations = 0
        self.episode_timesteps = 0
        self.episode_termination = []
        self.final_Euclid_dists = []
        self.change_Euclid_dists = []
        self.final_Quat_diffs = []
        self.change_Quat_diffs = []
        self.mean_rewards = []
        self.std_rewards = []
        self.num_term_per_100 = 0
        self.num_term_per_100_L = []

    def _on_step(self) -> bool:

        # extracting info dictionary
        info = self.locals["infos"][0]

        # extracting the Euclidean distance and quaternion difference
        observations = info.get("Observations")
        Euclid_dist = observations[0]
        Quat_diff = info.get("AngleDiff")

        # checking to see if it is the first timestep of this episode
        if self.episode_timesteps == 0:
            self.initial_Euclid_dist = Euclid_dist
            self.initial_Quat_diff = Quat_diff

        # update timestep counters
        self.timesteps += 1
        self.episode_timesteps += 1

        # print training progress every 1000 timesteps
        if self.timesteps % 1000 == 0:
            print(
                f"[{self.run_name}] "
                f"{self.timesteps}/{self.total_timesteps_target} timesteps | "
                f"episodes: {self.number_of_episodes} | "
                f"terminations: {self.terminations}"
            )

        # get done flag
        if "dones" in self.locals:
            done = self.locals["dones"][0]
        else:
            raise KeyError("Missing 'dones' in self.locals. Check environment compatibility.")

        # see whether the episode has finished
        if done:

            # record episode number
            self.number_of_episodes += 1

            # record episode reward
            self.episode_rewards.append(self.cum_rewards)

            # reset episode counters
            self.cum_rewards = 0.0
            self.episode_timesteps = 0

            # record final Euclidean distance
            self.final_Euclid_dists.append(Euclid_dist)

            # record final quaternion difference
            self.final_Quat_diffs.append(Quat_diff)

            # calculate and record the change in Euclidean distance
            change_Euclid_dist = Euclid_dist - self.initial_Euclid_dist
            self.change_Euclid_dists.append(change_Euclid_dist)

            # calculate and record the change in quaternion difference
            change_Quat_diff = Quat_diff - self.initial_Quat_diff
            self.change_Quat_diffs.append(change_Quat_diff)

            # checking to see if robot reached target
            if info.get("Terminated") is True:
                self.terminations += 1
                self.num_term_per_100 += 1
                self.episode_termination.append(self.number_of_episodes)

        # evaluate every 5000 timesteps
        if self.timesteps % 5000 == 0:
            mean_reward, std_reward = evaluate_policy(
                self.model,
                self.training_env,
                n_eval_episodes=20,
                deterministic=True
            )
            self.mean_rewards.append(mean_reward)
            self.std_rewards.append(std_reward)
            self.num_term_per_100_L.append(self.num_term_per_100)

        # record the reward of the step taken
        reward = float(self.locals["rewards"][0])
        self.cum_rewards += reward

        return True

    def _on_training_end(self) -> None:

        # save arrays
        np.savetxt(f"results/{self.run_name}_reward.txt", np.array(self.episode_rewards))
        np.savetxt(f"results/{self.run_name}_fEuclid.txt", np.array(self.final_Euclid_dists))
        np.savetxt(f"results/{self.run_name}_cEuclid.txt", np.array(self.change_Euclid_dists))
        np.savetxt(f"results/{self.run_name}_fQuat.txt", np.array(self.final_Quat_diffs))
        np.savetxt(f"results/{self.run_name}_cQuat.txt", np.array(self.change_Quat_diffs))
        np.savetxt(f"results/{self.run_name}_mreward.txt", np.array(self.mean_rewards))
        np.savetxt(f"results/{self.run_name}_stdreward.txt", np.array(self.std_rewards))
        np.savetxt(f"results/{self.run_name}_numterm.txt", np.array([self.terminations]))

        # save summary json
        summary = {
            "run_name": self.run_name,
            "num_episodes": self.number_of_episodes,
            "num_terminations": self.terminations,
        }
        with open(f"results/{self.run_name}_summary.json", "w") as f:
            json.dump(summary, f, indent=2)

        # print final summary
        print("Number of episodes:", self.number_of_episodes)
        print("Number of terminations:", self.terminations)

        # plotting graphs
        plt.figure(figsize=(15, 8))

        # rewards vs episode number
        plt.subplot(2, 3, 1)
        plt.plot(self.episode_rewards)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Cumulative Reward")
        plt.title("Cumulative Rewards VS Episode Number")

        # final Euclidean distance vs episode number
        plt.subplot(2, 3, 2)
        plt.plot(self.final_Euclid_dists)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Euclidean Distance (m)")
        plt.title("Final Euclidean Distance VS Episode Number")

        # change in Euclidean distance vs episode number
        plt.subplot(2, 3, 3)
        plt.plot(self.change_Euclid_dists)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Change in Euclidean Distance (m)")
        plt.title("Change in Euclidean Distance VS Episode Number")

        # final Quaternion difference vs episode number
        plt.subplot(2, 3, 4)
        plt.plot(self.final_Quat_diffs)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Final Quaternion Difference (rad)")
        plt.title("Final Quaternion Difference VS Episode Number")

        # change in Quaternion Difference vs episode number
        plt.subplot(2, 3, 5)
        plt.plot(self.change_Quat_diffs)
        plt.xlabel("Number of Episodes")
        plt.ylabel("Change in Quaternion Difference (rad)")
        plt.title("Change in Quaternion Difference VS Episode Number")

        plt.tight_layout()
        plt.savefig(f"results/{self.run_name}_plots.png", dpi=300, bbox_inches="tight")
        plt.show()

# %%
# wrapping environment
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.monitor import Monitor
import os

# instantating arrayy containing the mean rewards and standard deviation to be computed at the end of each set of 100,000 steps
mean_rewards_arr = np.array(range(10))
std_rewards_arr = np.array(range(10))

# instantiate the robot arm custom environment and wrap with a monitor wrapper
env = Monitor(RightArmRobot())

# %%
# checking the environment
# If the environment don't follow the interface, an error will be thrown
check_env(env, warn=True)

# %%
import os
os.makedirs("models", exist_ok=True)
os.makedirs("results", exist_ok=True)

# %%
# training Agent
from stable_baselines3 import SAC
import matplotlib.pyplot as plt
TOTAL_TIMESTEPS = 500000

# Instantiate the callback
plotting_callback = CustomCallback(run_name="progressnew_500k", total_timesteps=TOTAL_TIMESTEPS)

# training SAC model for the custom environment
model = SAC("MlpPolicy", env, verbose=0).learn(total_timesteps=TOTAL_TIMESTEPS, callback=plotting_callback, log_interval=1)

# saving the model and replay buffer after the training
model.save("models/progressnew_500k_model")
model.save_replay_buffer("models/progressnew_500k_replaybuffer")
# Out:
# [progressnew_500k] 1000/500000 timesteps | episodes: 3 | terminations: 0
# [progressnew_500k] 2000/500000 timesteps | episodes: 6 | terminations: 0
# [progressnew_500k] 3000/500000 timesteps | episodes: 9 | terminations: 0
# Terminated
# Target position x:  0.09755865243005235
# Target position y:  0.509368759746675
# Target position z:  0.2379334328824979
# [progressnew_500k] 4000/500000 timesteps | episodes: 13 | terminations: 1
# Terminated
# Target position x:  0.16880332558645492
# Target position y:  0.6049315235011867
# Target position z:  0.15178706230109265
# [progressnew_500k] 5000/500000 timesteps | episodes: 17 | terminations: 2
# [progressnew_500k] 6000/500000 timesteps | episodes: 20 | terminations: 2
# [progressnew_500k] 7000/500000 timesteps | episodes: 23 | terminations: 2
# [progressnew_500k] 8000/500000 timesteps | episodes: 26 | terminations: 2
# [progressnew_500k] 9000/500000 timesteps | episodes: 30 | terminations: 2
# [progressnew_500k] 10000/500000 timesteps | episodes: 33 | terminations: 2
# [progressnew_500k] 11000/500000 timesteps | episodes: 36 | terminations: 2
# Terminated
# Target position x:  0.1076683766136377
# Target position y:  0.4879689467749889
# Target position z:  0.26030100032658265
# Terminated
# Target position x:  0.13439759084235112
# Target position y:  0.49115196314199133
# Target position z:  0.2533865781385275
# Terminated
# Target position x:  0.0561721340570667
# Target position y:  0.5123678623443737
# Target position z:  0.17292501348205286
# [progressnew_500k] 12000/500000 timesteps | episodes: 42 | terminations: 5
# [progressnew_500k] 13000/500000 timesteps | episodes: 45 | terminations: 5
# Terminated
# Target position x:  0.1893347990642022
# Target position y:  0.43180060135129367
# Target position z:  0.2002023424331626
# [progressnew_500k] 14000/500000 timesteps | episodes: 48 | terminations: 6
# [progressnew_500k] 15000/500000 timesteps | episodes: 52 | terminations: 6
# Terminated
# Target position x:  0.06575159373076672
# Target position y:  0.3748970736141788
# Target position z:  0.21450173295717684
# Terminated
# Target position x:  0.01008071690887602
# Target position y:  0.4033184079279182
# Target position z:  0.30367114397605643
# Terminated
# Target position x:  0.15852432214767193
# Target position y:  0.5194690816826479
# Target position z:  0.22345304656431286
# [progressnew_500k] 16000/500000 timesteps | episodes: 55 | terminations: 7
# Terminated
# Target position x:  0.16561179209554566
# Target position y:  0.486163315857739
# Target position z:  0.29382083703149325
# Terminated
# Target position x:  0.057902025556949926
# Target position y:  0.5519230078558296
# Target position z:  0.19500238821475055
# Terminated
# Target position x:  0.09637797908740842
# Target position y:  0.5356481163256306
# Target position z:  0.2546840543773158
# [progressnew_500k] 17000/500000 timesteps | episodes: 60 | terminations: 10
# Terminated
# Target position x:  0.22764334610751039
# Target position y:  0.4524814796152242
# Target position z:  0.18977650594279266
# [progressnew_500k] 18000/500000 timesteps | episodes: 64 | terminations: 11
# Terminated
# Target position x:  0.07633245317856324
# Target position y:  0.46554721400500765
# Target position z:  0.25413060422431255
# [progressnew_500k] 19000/500000 timesteps | episodes: 68 | terminations: 12
# Terminated
# Target position x:  0.2010629412394488
# Target position y:  0.4629543407993191
# Target position z:  0.25202334102791496
# [progressnew_500k] 20000/500000 timesteps | episodes: 72 | terminations: 13
# Terminated
# Target position x:  0.11751124955197562
# Target position y:  0.38449342446214235
# Target position z:  0.3427726266149201
# Terminated
# Target position x:  0.028937207889640465
# Target position y:  0.33038246161763724
# Target position z:  0.1601704585574392
# Terminated
# Target position x:  0.22358971563006158
# Target position y:  0.5050878362309668
# Target position z:  0.2665076138783808
# [progressnew_500k] 21000/500000 timesteps | episodes: 76 | terminations: 14
# Terminated
# Target position x:  0.16143940632700976
# Target position y:  0.3702428260599129
# Target position z:  0.3327113050792532
# [progressnew_500k] 22000/500000 timesteps | episodes: 80 | terminations: 15
# Terminated
# Target position x:  0.10021775657539364
# Target position y:  0.48758507117179956
# Target position z:  0.1606876215789771
# [progressnew_500k] 23000/500000 timesteps | episodes: 84 | terminations: 16
# Terminated
# Target position x:  0.22182321951537784
# Target position y:  0.5014993685567266
# Target position z:  0.19992927166668517
# [progressnew_500k] 24000/500000 timesteps | episodes: 87 | terminations: 17
# Terminated
# Target position x:  0.1950215182573495
# Target position y:  0.3872539626498369
# Target position z:  0.16339884214442216
# [progressnew_500k] 25000/500000 timesteps | episodes: 91 | terminations: 18
# Terminated
# Target position x:  0.20651394214415825
# Target position y:  0.545741775129257
# Target position z:  0.21803920688921144
# Terminated
# Target position x:  0.13559077098953015
# Target position y:  0.5437006559614621
# Target position z:  0.18006680057538438
# Terminated
# Target position x:  0.05153342973155922
# Target position y:  0.5986299350047679
# Target position z:  0.3321609107846212
# Terminated
# Target position x:  0.24849459312344346
# Target position y:  0.48142072891666915
# Target position z:  0.2693218063601559
# [progressnew_500k] 26000/500000 timesteps | episodes: 95 | terminations: 20
# Terminated
# Target position x:  0.02520045109674851
# Target position y:  0.6077558795865967
# Target position z:  0.34974081677835545
# Terminated
# Target position x:  0.01250661119300514
# Target position y:  0.32372148970117093
# Target position z:  0.25473326235733285
# [progressnew_500k] 27000/500000 timesteps | episodes: 100 | terminations: 22
# Terminated
# Target position x:  0.18995811363260345
# Target position y:  0.5462713073687229
# Target position z:  0.16014849524699387
# [progressnew_500k] 28000/500000 timesteps | episodes: 103 | terminations: 23
# Terminated
# Target position x:  0.07692009743226905
# Target position y:  0.35231093043902617
# Target position z:  0.18881963454316672
# Terminated
# Target position x:  0.11452313856555205
# Target position y:  0.5287153654469865
# Target position z:  0.2934153848969028
# Terminated
# Target position x:  0.1431918895840972
# Target position y:  0.3404369806686235
# Target position z:  0.31623577589938046
# [progressnew_500k] 29000/500000 timesteps | episodes: 109 | terminations: 26
# Terminated
# Target position x:  0.10519947581419484
# Target position y:  0.4519368787777669
# Target position z:  0.15240853025419843
# Terminated
# Target position x:  0.1123020658236493
# Target position y:  0.47691290384827656
# Target position z:  0.2289217473184445
# Terminated
# Target position x:  0.028197702413811837
# Target position y:  0.4901000398424411
# Target position z:  0.2200064759053392
# [progressnew_500k] 30000/500000 timesteps | episodes: 115 | terminations: 29
# Terminated
# Target position x:  0.009794091133780214
# Target position y:  0.3860042998571031
# Target position z:  0.2188520569517552
# Terminated
# Target position x:  0.07694673329312643
# Target position y:  0.6234258998503885
# Target position z:  0.31301293369160815
# Terminated
# Target position x:  0.11545060147460576
# Target position y:  0.5152514986058557
# Target position z:  0.33048910660330627
# Terminated
# Target position x:  0.15847016196780092
# Target position y:  0.40767011788475305
# Target position z:  0.30278085662358406
# Terminated
# Target position x:  0.0031227878997539815
# Target position y:  0.4892414188832012
# Target position z:  0.29384726628134683
# [progressnew_500k] 31000/500000 timesteps | episodes: 120 | terminations: 33
# Terminated
# Target position x:  0.19135601208018074
# Target position y:  0.5795741374035228
# Target position z:  0.3280566594192069
# Terminated
# Target position x:  0.18731770619334107
# Target position y:  0.4659459302141412
# Target position z:  0.20144368852137884
# Terminated
# Target position x:  0.21946596513079156
# Target position y:  0.4297583992005074
# Target position z:  0.24986592031468294
# Terminated
# Target position x:  0.15094102167331666
# Target position y:  0.6347501392630583
# Target position z:  0.3050339924903114
# [progressnew_500k] 32000/500000 timesteps | episodes: 125 | terminations: 37
# Terminated
# Target position x:  0.11261302943343462
# Target position y:  0.4784838474800378
# Target position z:  0.17822303557759853
# Terminated
# Target position x:  0.05214543369542338
# Target position y:  0.30843610028517865
# Target position z:  0.31177772962715644
# Terminated
# Target position x:  0.23551793917246833
# Target position y:  0.6067959893235466
# Target position z:  0.20985593313545398
# Terminated
# Target position x:  0.009216034904179243
# Target position y:  0.550422161494278
# Target position z:  0.23132899185044775
# [progressnew_500k] 33000/500000 timesteps | episodes: 130 | terminations: 41
# Terminated
# Target position x:  0.012087493484216671
# Target position y:  0.5321784905271465
# Target position z:  0.1994641750187534
# Terminated
# Target position x:  0.15614632313583215
# Target position y:  0.4383740267013044
# Target position z:  0.2406706167959171
# Terminated
# Target position x:  0.06392822947068169
# Target position y:  0.36202905532246166
# Target position z:  0.3398739034651585
# Terminated
# Target position x:  0.14358219111350365
# Target position y:  0.4944718528403321
# Target position z:  0.27193548760064146
# Terminated
# Target position x:  0.05224272106724254
# Target position y:  0.38210432203713685
# Target position z:  0.24884556084572934
# Terminated
# Target position x:  0.1268206271882319
# Target position y:  0.497275026079327
# Target position z:  0.20790166353340853
# [progressnew_500k] 34000/500000 timesteps | episodes: 138 | terminations: 47
# [progressnew_500k] 35000/500000 timesteps | episodes: 141 | terminations: 47
# Terminated
# Target position x:  0.22639632264644288
# Target position y:  0.4877061572267485
# Target position z:  0.18869903918099964
# Terminated
# Target position x:  0.10155629216787151
# Target position y:  0.5388325145297126
# Target position z:  0.22026585481568195
# Terminated
# Target position x:  0.15905367943274312
# Target position y:  0.4080037818421489
# Target position z:  0.2137249812490093
# Terminated
# Target position x:  0.18298961928078922
# Target position y:  0.36452181300478376
# Target position z:  0.29242717534344287
# Terminated
# Target position x:  0.1365432186353759
# Target position y:  0.5645694622527704
# Target position z:  0.26482981457212224
# Terminated
# Target position x:  0.11752375348544888
# Target position y:  0.3452655825188219
# Target position z:  0.22062553600419593
# Terminated
# Target position x:  0.187260560627936
# Target position y:  0.3037643215025835
# Target position z:  0.17896560819521837
# Terminated
# Target position x:  0.17801216622815264
# Target position y:  0.4358158065836284
# Target position z:  0.32759640695517167
# Terminated
# Target position x:  0.21711977886533218
# Target position y:  0.516684998655224
# Target position z:  0.2710210502295805
# Terminated
# Target position x:  0.10172635267041136
# Target position y:  0.3568142075290822
# Target position z:  0.18105530709280737
# [progressnew_500k] 36000/500000 timesteps | episodes: 146 | terminations: 51
# Terminated
# Target position x:  0.18050602588266043
# Target position y:  0.39973600663887876
# Target position z:  0.19511064560955052
# Terminated
# Target position x:  0.2149374465890276
# Target position y:  0.37581040479856137
# Target position z:  0.23065525435156164
# [progressnew_500k] 37000/500000 timesteps | episodes: 150 | terminations: 53
# Terminated
# Target position x:  0.09178364780062809
# Target position y:  0.5004390934080067
# Target position z:  0.32723512355788403
# Terminated
# Target position x:  0.20606894320192867
# Target position y:  0.5115695316263925
# Target position z:  0.19081799130686258
# [progressnew_500k] 38000/500000 timesteps | episodes: 156 | terminations: 55
# Terminated
# Target position x:  0.09120965373100948
# Target position y:  0.5580789776811381
# Target position z:  0.3071713426719778
# Terminated
# Target position x:  0.13933661962622051
# Target position y:  0.4465401151435539
# Target position z:  0.3430307744274791
# [progressnew_500k] 39000/500000 timesteps | episodes: 161 | terminations: 57
# Terminated
# Target position x:  0.014587905378051685
# Target position y:  0.3089490226220132
# Target position z:  0.3104979238644865
# Terminated
# Target position x:  0.19031920382053383
# Target position y:  0.39464812237454233
# Target position z:  0.26910439894716626
# [progressnew_500k] 40000/500000 timesteps | episodes: 165 | terminations: 59
# Terminated
# Target position x:  0.163044722633252
# Target position y:  0.6394265795964813
# Target position z:  0.1664999248632809
# Terminated
# Target position x:  0.24218353063326153
# Target position y:  0.5747338712427188
# Target position z:  0.17513867023349128
# Terminated
# Target position x:  0.1534953301375833
# Target position y:  0.464134554374274
# Target position z:  0.3124765775994212
# Terminated
# Target position x:  0.0632300825376296
# Target position y:  0.43708019053158315
# Target position z:  0.31911325054368145
# Terminated
# Target position x:  0.15847791263276967
# Target position y:  0.4764280241020781
# Target position z:  0.2312505697232038
# [progressnew_500k] 41000/500000 timesteps | episodes: 168 | terminations: 60
# Terminated
# Target position x:  0.20185887760122048
# Target position y:  0.474191088077717
# Target position z:  0.29186590018124114
# Terminated
# Target position x:  0.09246005457503595
# Target position y:  0.4972575170124805
# Target position z:  0.18998754224370643
# Terminated
# Target position x:  0.16292808409789586
# Target position y:  0.382294869611029
# Target position z:  0.20271571042065534
# [progressnew_500k] 42000/500000 timesteps | episodes: 174 | terminations: 63
# Terminated
# Target position x:  0.033185844061795366
# Target position y:  0.4655766258726869
# Target position z:  0.15753661601953428
# [progressnew_500k] 43000/500000 timesteps | episodes: 178 | terminations: 64
# Terminated
# Target position x:  0.01806579551273446
# Target position y:  0.4092194074035929
# Target position z:  0.28774444931935717
# Terminated
# Target position x:  0.1747989486444136
# Target position y:  0.4988489511857427
# Target position z:  0.23086699065580146
# [progressnew_500k] 44000/500000 timesteps | episodes: 183 | terminations: 66
# Terminated
# Target position x:  0.18681226009559654
# Target position y:  0.46806116961297295
# Target position z:  0.24005133549147994
# [progressnew_500k] 45000/500000 timesteps | episodes: 187 | terminations: 67
# Terminated
# Target position x:  0.13123116001649512
# Target position y:  0.5530012571950982
# Target position z:  0.22782560832761092
# Terminated
# Target position x:  0.12553900173062132
# Target position y:  0.45056097096149816
# Target position z:  0.25902177069547644
# Terminated
# Target position x:  0.1377152218314534
# Target position y:  0.47868865285050866
# Target position z:  0.25530730364664866
# Terminated
# Target position x:  0.004417257838444794
# Target position y:  0.5556429493593504
# Target position z:  0.15117280369478323
# Terminated
# Target position x:  0.15652116695715038
# Target position y:  0.49329122980354906
# Target position z:  0.17374771613983564
# Terminated
# Target position x:  0.00931949161535392
# Target position y:  0.40323635859852824
# Target position z:  0.23642665507867022
# [progressnew_500k] 46000/500000 timesteps | episodes: 191 | terminations: 69
# [progressnew_500k] 47000/500000 timesteps | episodes: 194 | terminations: 69
# [progressnew_500k] 48000/500000 timesteps | episodes: 197 | terminations: 69
# Terminated
# Target position x:  0.010548126179064032
# Target position y:  0.40268159483937493
# Target position z:  0.26766742579078096
# [progressnew_500k] 49000/500000 timesteps | episodes: 201 | terminations: 70
# Terminated
# Target position x:  0.2012892881891247
# Target position y:  0.3936659964586245
# Target position z:  0.34622331880635987
# [progressnew_500k] 50000/500000 timesteps | episodes: 205 | terminations: 71
# Terminated
# Target position x:  0.1663557310400467
# Target position y:  0.3456815310758809
# Target position z:  0.1687581803748739
# Terminated
# Target position x:  0.13709463036136293
# Target position y:  0.40743885448933936
# Target position z:  0.2140921807938677
# Terminated
# Target position x:  0.12709201266101475
# Target position y:  0.5014388290886176
# Target position z:  0.332673573438129
# [progressnew_500k] 51000/500000 timesteps | episodes: 208 | terminations: 72
# [progressnew_500k] 52000/500000 timesteps | episodes: 212 | terminations: 72
# Terminated
# Target position x:  0.20549609716787165
# Target position y:  0.5915915429728091
# Target position z:  0.16673178877405168
# Terminated
# Target position x:  0.23971263861203243
# Target position y:  0.560382798821624
# Target position z:  0.28933370360687893
# Terminated
# Target position x:  0.18609058009229074
# Target position y:  0.4580943269133342
# Target position z:  0.244867130792557
# [progressnew_500k] 53000/500000 timesteps | episodes: 217 | terminations: 75
# Terminated
# Target position x:  0.20121308624616216
# Target position y:  0.35027352736032263
# Target position z:  0.2630681127432163
# Terminated
# Target position x:  0.14654960362042882
# Target position y:  0.34934561296440403
# Target position z:  0.297864888809241
# Terminated
# Target position x:  0.11265958990268995
# Target position y:  0.5491041453384994
# Target position z:  0.2609547827380074
# [progressnew_500k] 54000/500000 timesteps | episodes: 223 | terminations: 78
# Terminated
# Target position x:  0.052079372229133836
# Target position y:  0.3505918891564378
# Target position z:  0.27698035602406834
# [progressnew_500k] 55000/500000 timesteps | episodes: 227 | terminations: 79
# Terminated
# Target position x:  0.027019659881401675
# Target position y:  0.4564743648095176
# Target position z:  0.34530730476819954
# Terminated
# Target position x:  0.023120499818154228
# Target position y:  0.4309958240404369
# Target position z:  0.3408904277805639
# [progressnew_500k] 56000/500000 timesteps | episodes: 230 | terminations: 79
# Terminated
# Target position x:  0.21646309154135476
# Target position y:  0.45968341865108975
# Target position z:  0.268901292671413
# Terminated
# Target position x:  0.23382077481227287
# Target position y:  0.4994076154255913
# Target position z:  0.28827908710432004
# Terminated
# Target position x:  0.07823092690906486
# Target position y:  0.3266413699857166
# Target position z:  0.2950027836055593
# Terminated
# Target position x:  0.15508668462582212
# Target position y:  0.5228539722744343
# Target position z:  0.3035754758009115
# [progressnew_500k] 57000/500000 timesteps | episodes: 236 | terminations: 83
# Terminated
# Target position x:  0.15315626426331821
# Target position y:  0.5125642975183677
# Target position z:  0.20898249468289132
# [progressnew_500k] 58000/500000 timesteps | episodes: 239 | terminations: 84
# Terminated
# Target position x:  0.15730125502975836
# Target position y:  0.5955222188429434
# Target position z:  0.1571120393556182
# Terminated
# Target position x:  0.11318025250928962
# Target position y:  0.46733700719345705
# Target position z:  0.33157024911206817
# [progressnew_500k] 59000/500000 timesteps | episodes: 244 | terminations: 86
# Terminated
# Target position x:  0.18674079987951614
# Target position y:  0.5457534582284751
# Target position z:  0.3483228181948603
# Terminated
# Target position x:  0.003799107433854587
# Target position y:  0.5529557951445132
# Target position z:  0.3098624411359915
# [progressnew_500k] 60000/500000 timesteps | episodes: 248 | terminations: 88
# Terminated
# Target position x:  0.15867805612736585
# Target position y:  0.47518709758617267
# Target position z:  0.2979789170613339
# Terminated
# Target position x:  0.21839392112038114
# Target position y:  0.5839139330587214
# Target position z:  0.31750725375567646
# Terminated
# Target position x:  0.038253741385087664
# Target position y:  0.39512979263245346
# Target position z:  0.3360341676547928
# Terminated
# Target position x:  0.1506952196165952
# Target position y:  0.4017504141893735
# Target position z:  0.24423912558956776
# [progressnew_500k] 61000/500000 timesteps | episodes: 254 | terminations: 91
# Terminated
# Target position x:  0.2420288919237956
# Target position y:  0.39126787065993646
# Target position z:  0.20458803190293107
# Terminated
# Target position x:  0.060444737879075755
# Target position y:  0.4892159025234165
# Target position z:  0.3393884320049313
# Terminated
# Target position x:  0.04269211556377861
# Target position y:  0.5059583160981219
# Target position z:  0.3325615466542023
# Terminated
# Target position x:  0.14439529655252176
# Target position y:  0.555400021379359
# Target position z:  0.2842648026046177
# Terminated
# Target position x:  0.19911377507570047
# Target position y:  0.49485725029253086
# Target position z:  0.31498936680774825
# [progressnew_500k] 62000/500000 timesteps | episodes: 261 | terminations: 96
# Terminated
# Target position x:  0.19549832090453137
# Target position y:  0.5297450913544105
# Target position z:  0.17193743169764703
# Terminated
# Target position x:  0.11487284813383056
# Target position y:  0.31820516902017526
# Target position z:  0.3434196637786271
# Terminated
# Target position x:  0.13486299840513227
# Target position y:  0.42640448267888287
# Target position z:  0.17153044948571128
# Terminated
# Target position x:  0.22317792635467323
# Target position y:  0.47014728339540846
# Target position z:  0.33101064044920514
# Terminated
# Target position x:  0.18362232698271644
# Target position y:  0.44408440411569894
# Target position z:  0.2534818737447098
# [progressnew_500k] 63000/500000 timesteps | episodes: 267 | terminations: 101
# Terminated
# Target position x:  0.12992804676990663
# Target position y:  0.5924172925284913
# Target position z:  0.3142200605011255
# Terminated
# Target position x:  0.004784776515856626
# Target position y:  0.592235735642804
# Target position z:  0.19043294208651065
# [progressnew_500k] 64000/500000 timesteps | episodes: 272 | terminations: 103
# Terminated
# Target position x:  0.11602543634005219
# Target position y:  0.4212304578421729
# Target position z:  0.27136489217408233
# [progressnew_500k] 65000/500000 timesteps | episodes: 276 | terminations: 104
# Terminated
# Target position x:  0.1286849797402927
# Target position y:  0.6376774138638617
# Target position z:  0.19698413007624116
# Terminated
# Target position x:  0.2407744288689942
# Target position y:  0.3479460327286144
# Target position z:  0.25346613366267207
# Terminated
# Target position x:  0.04134789238303746
# Target position y:  0.543739892694147
# Target position z:  0.155091586507351
# Terminated
# Target position x:  0.0395404294868599
# Target position y:  0.5308935732300768
# Target position z:  0.3481613023238016
# Terminated
# Target position x:  0.12412569251728925
# Target position y:  0.38241849402626005
# Target position z:  0.31423243052788064
# Terminated
# Target position x:  0.028951427123684342
# Target position y:  0.30288773435462496
# Target position z:  0.2548101962400625
# Terminated
# Target position x:  0.015015231601266305
# Target position y:  0.4906679299943669
# Target position z:  0.2525897103271166
# [progressnew_500k] 66000/500000 timesteps | episodes: 282 | terminations: 108
# Terminated
# Target position x:  0.23678792887412553
# Target position y:  0.49969989925969893
# Target position z:  0.24971801332669602
# Terminated
# Target position x:  0.17392831481315407
# Target position y:  0.4046855104269458
# Target position z:  0.23584984991851243
# [progressnew_500k] 67000/500000 timesteps | episodes: 286 | terminations: 110
# Terminated
# Target position x:  0.20778945183460415
# Target position y:  0.4222897002155034
# Target position z:  0.15566087955123162
# Terminated
# Target position x:  0.10541836546103023
# Target position y:  0.38233232875954176
# Target position z:  0.2047457242211741
# Terminated
# Target position x:  0.2249400031981995
# Target position y:  0.6018553880117763
# Target position z:  0.2626606425186457
# [progressnew_500k] 68000/500000 timesteps | episodes: 292 | terminations: 113
# [progressnew_500k] 69000/500000 timesteps | episodes: 295 | terminations: 113
# Terminated
# Target position x:  0.019990693573545743
# Target position y:  0.5066038149504534
# Target position z:  0.2563772744949804
# Terminated
# Target position x:  0.1754265124950509
# Target position y:  0.5108967491489126
# Target position z:  0.2874256436561769
# [progressnew_500k] 70000/500000 timesteps | episodes: 299 | terminations: 115
# Terminated
# Target position x:  0.21339642667380174
# Target position y:  0.44373914809429643
# Target position z:  0.22027173912157036
# Terminated
# Target position x:  0.019194051585448874
# Target position y:  0.63957182354765
# Target position z:  0.30326847612646646
# Terminated
# Target position x:  0.10781586831321507
# Target position y:  0.5263234192950786
# Target position z:  0.3318773967952799
# [progressnew_500k] 71000/500000 timesteps | episodes: 302 | terminations: 115
# Terminated
# Target position x:  0.13473873621648502
# Target position y:  0.33319880935900503
# Target position z:  0.15351456945221745
# Terminated
# Target position x:  0.10746463570708986
# Target position y:  0.5230641101073924
# Target position z:  0.20134630493796635
# Terminated
# Target position x:  0.20606640468004922
# Target position y:  0.3382479104311583
# Target position z:  0.22569477314051567
# [progressnew_500k] 72000/500000 timesteps | episodes: 307 | terminations: 118
# Terminated
# Target position x:  0.03123747597195123
# Target position y:  0.400262731033122
# Target position z:  0.28860329888572456
# [progressnew_500k] 73000/500000 timesteps | episodes: 311 | terminations: 119
# Terminated
# Target position x:  0.16150011947855858
# Target position y:  0.5751585260469856
# Target position z:  0.2052436043087063
# Terminated
# Target position x:  0.05910521424684376
# Target position y:  0.3600320713014945
# Target position z:  0.25335435673676365
# Terminated
# Target position x:  0.02254448397110037
# Target position y:  0.5445297026570488
# Target position z:  0.22855502551503995
# [progressnew_500k] 74000/500000 timesteps | episodes: 316 | terminations: 122
# Terminated
# Target position x:  0.05931727291116637
# Target position y:  0.4366102105720979
# Target position z:  0.22010685496248591
# Terminated
# Target position x:  0.045798371476024724
# Target position y:  0.42467380101340557
# Target position z:  0.1598524114104917
# [progressnew_500k] 75000/500000 timesteps | episodes: 321 | terminations: 124
# Terminated
# Target position x:  0.16617726029882132
# Target position y:  0.5025160666164041
# Target position z:  0.17609457732264422
# Terminated
# Target position x:  0.17006534741314214
# Target position y:  0.49495808284368364
# Target position z:  0.2957715090676678
# Terminated
# Target position x:  0.1007136639114217
# Target position y:  0.556285513384474
# Target position z:  0.21619613397345874
# [progressnew_500k] 76000/500000 timesteps | episodes: 325 | terminations: 125
# Terminated
# Target position x:  0.23272082953619144
# Target position y:  0.41437989604600994
# Target position z:  0.2617953232987874
# Terminated
# Target position x:  0.09157875131675647
# Target position y:  0.5546822545743897
# Target position z:  0.3027082278393171
# Terminated
# Target position x:  0.22861575875361792
# Target position y:  0.5360014170371477
# Target position z:  0.25290070192840924
# [progressnew_500k] 77000/500000 timesteps | episodes: 330 | terminations: 128
# Terminated
# Target position x:  0.15471653103862867
# Target position y:  0.6145717432672875
# Target position z:  0.27720116155434016
# Terminated
# Target position x:  0.1008447232198425
# Target position y:  0.5057833832094714
# Target position z:  0.2163754132237602
# Terminated
# Target position x:  0.025860110553245025
# Target position y:  0.5961644650370568
# Target position z:  0.21404537498820364
# Terminated
# Target position x:  0.14062925091044795
# Target position y:  0.345505001253712
# Target position z:  0.2549751774990171
# [progressnew_500k] 78000/500000 timesteps | episodes: 336 | terminations: 132
# Terminated
# Target position x:  0.0924637522527956
# Target position y:  0.6444116339612197
# Target position z:  0.3467946016900894
# Terminated
# Target position x:  0.22202926692516073
# Target position y:  0.37619209934029946
# Target position z:  0.20029088579390017
# [progressnew_500k] 79000/500000 timesteps | episodes: 340 | terminations: 134
# Terminated
# Target position x:  0.023148791882677544
# Target position y:  0.5124729575937621
# Target position z:  0.28890777132206136
# Terminated
# Target position x:  0.07867894388399085
# Target position y:  0.42167219414695806
# Target position z:  0.17961750514101693
# Terminated
# Target position x:  0.03964392631621699
# Target position y:  0.3047991932726517
# Target position z:  0.2737999047636737
# Terminated
# Target position x:  0.1306688022710154
# Target position y:  0.37151422667553663
# Target position z:  0.1690472286276424
# [progressnew_500k] 80000/500000 timesteps | episodes: 345 | terminations: 138
# Terminated
# Target position x:  0.11286019944229478
# Target position y:  0.4593436749948299
# Target position z:  0.27079843691235955
# Terminated
# Target position x:  0.09345680316638247
# Target position y:  0.39794693316829904
# Target position z:  0.15844933519019216
# Terminated
# Target position x:  0.24701474944313212
# Target position y:  0.5623664050089909
# Target position z:  0.33677151751083434
# Terminated
# Target position x:  0.17821899469578034
# Target position y:  0.4094446708156183
# Target position z:  0.24512333758965765
# Terminated
# Target position x:  0.1683300307380908
# Target position y:  0.32014472986110554
# Target position z:  0.1556139909244099
# Terminated
# Target position x:  0.19042652407388755
# Target position y:  0.5237260727604156
# Target position z:  0.24742520082870073
# Terminated
# Target position x:  0.20512220036267614
# Target position y:  0.47374767665847417
# Target position z:  0.19081063268323467
# Terminated
# Target position x:  0.05578856678486685
# Target position y:  0.6255959621517279
# Target position z:  0.33590299587055905
# [progressnew_500k] 81000/500000 timesteps | episodes: 349 | terminations: 140
# Terminated
# Target position x:  0.04559618923974543
# Target position y:  0.5767312345767854
# Target position z:  0.30423752407409077
# Terminated
# Target position x:  0.0623715755354847
# Target position y:  0.5987114809678198
# Target position z:  0.20141774690405023
# [progressnew_500k] 82000/500000 timesteps | episodes: 355 | terminations: 142
# Terminated
# Target position x:  0.14127713606142406
# Target position y:  0.4435349276923244
# Target position z:  0.30391376026852934
# Terminated
# Target position x:  0.08508816361768887
# Target position y:  0.5104652593932523
# Target position z:  0.30244739752185357
# Terminated
# Target position x:  0.11545323244129843
# Target position y:  0.5935425467679559
# Target position z:  0.24486143575648606
# Terminated
# Target position x:  0.19089039521845141
# Target position y:  0.5965736450017494
# Target position z:  0.23542750357670017
# [progressnew_500k] 83000/500000 timesteps | episodes: 361 | terminations: 146
# Terminated
# Target position x:  0.05415975256711805
# Target position y:  0.5501271690267588
# Target position z:  0.3238180734369984
# Terminated
# Target position x:  0.10647633259110229
# Target position y:  0.3017244409085039
# Target position z:  0.2355105943382821
# Terminated
# Target position x:  0.0983768016244059
# Target position y:  0.35157368055291205
# Target position z:  0.17439411349693223
# [progressnew_500k] 84000/500000 timesteps | episodes: 367 | terminations: 149
# Terminated
# Target position x:  0.007946994773534749
# Target position y:  0.5439281672424172
# Target position z:  0.2334452332935663
# Terminated
# Target position x:  0.026374715405990373
# Target position y:  0.3429289775406029
# Target position z:  0.20337468237802614
# [progressnew_500k] 85000/500000 timesteps | episodes: 371 | terminations: 151
# Terminated
# Target position x:  0.1559074499242901
# Target position y:  0.4208586256989145
# Target position z:  0.3011097755714463
# Terminated
# Target position x:  0.10807888932912652
# Target position y:  0.5971569070561233
# Target position z:  0.22893611661390323
# Terminated
# Target position x:  0.05513856945348625
# Target position y:  0.57572214945053
# Target position z:  0.3093448882933217
# Terminated
# Target position x:  0.11663252654648182
# Target position y:  0.507385733638895
# Target position z:  0.28161488078925057
# Terminated
# Target position x:  0.017776015440087722
# Target position y:  0.47209802403224044
# Target position z:  0.20783291886014246
# [progressnew_500k] 86000/500000 timesteps | episodes: 375 | terminations: 153
# Terminated
# Target position x:  0.1322964865140863
# Target position y:  0.3938142565756142
# Target position z:  0.20925087980936774
# Terminated
# Target position x:  0.228825861461856
# Target position y:  0.3692331091544774
# Target position z:  0.26034972002730356
# Terminated
# Target position x:  0.10295701118329334
# Target position y:  0.4056002209569815
# Target position z:  0.322418161789637
# Terminated
# Target position x:  0.153915142240761
# Target position y:  0.35933813596937064
# Target position z:  0.2631479975862114
# Terminated
# Target position x:  0.08822091385365236
# Target position y:  0.39844304844034845
# Target position z:  0.25315030594124566
# [progressnew_500k] 87000/500000 timesteps | episodes: 383 | terminations: 158
# Terminated
# Target position x:  0.1279287249362923
# Target position y:  0.5039549908420885
# Target position z:  0.2762927546870927
# Terminated
# Target position x:  0.0707433003125243
# Target position y:  0.509233842140071
# Target position z:  0.2648404291201646
# Terminated
# Target position x:  0.1498313712583332
# Target position y:  0.31716369526292365
# Target position z:  0.34005467841735953
# Terminated
# Target position x:  0.11385272533673005
# Target position y:  0.4419474840219855
# Target position z:  0.1925789377792918
# [progressnew_500k] 88000/500000 timesteps | episodes: 389 | terminations: 162
# Terminated
# Target position x:  0.19717105075272062
# Target position y:  0.33345347996929275
# Target position z:  0.19009694800176657
# Terminated
# Target position x:  0.0396310387935539
# Target position y:  0.6123570307515885
# Target position z:  0.3046032705269028
# Terminated
# Target position x:  0.05382733149460156
# Target position y:  0.6117445229675722
# Target position z:  0.24176107363652513
# [progressnew_500k] 89000/500000 timesteps | episodes: 394 | terminations: 165
# Terminated
# Target position x:  0.16626425593812552
# Target position y:  0.3571911609069559
# Target position z:  0.23044154334784558
# Terminated
# Target position x:  0.0161213737463915
# Target position y:  0.4611130409331728
# Target position z:  0.3493137729386813
# [progressnew_500k] 90000/500000 timesteps | episodes: 398 | terminations: 167
# Terminated
# Target position x:  0.21354421188972167
# Target position y:  0.557557052467103
# Target position z:  0.3083525389044409
# Terminated
# Target position x:  0.07005798725009779
# Target position y:  0.6271246108936326
# Target position z:  0.34958487902111657
# Terminated
# Target position x:  0.025968525836084055
# Target position y:  0.5516997887458506
# Target position z:  0.2860779597246557
# Terminated
# Target position x:  0.04904661447181902
# Target position y:  0.5934981461130258
# Target position z:  0.2950566313542886
# Terminated
# Target position x:  0.03636443698905553
# Target position y:  0.46183089089873025
# Target position z:  0.2100580622604474
# Terminated
# Target position x:  0.11187785990862562
# Target position y:  0.5364363026191942
# Target position z:  0.23067458695696863
# Terminated
# Target position x:  0.0998004895118389
# Target position y:  0.4972383221034473
# Target position z:  0.32879409945118154
# Terminated
# Target position x:  0.2125784979938812
# Target position y:  0.41555673180821984
# Target position z:  0.2960926616405085
# [progressnew_500k] 91000/500000 timesteps | episodes: 402 | terminations: 169
# Terminated
# Target position x:  0.11218299376661808
# Target position y:  0.5160795993368132
# Target position z:  0.17839865234381788
# Terminated
# Target position x:  0.0033572297440338794
# Target position y:  0.5869088815536337
# Target position z:  0.2741403806818671
# Terminated
# Target position x:  0.18221219862113747
# Target position y:  0.31153722816615914
# Target position z:  0.27648596177379553
# [progressnew_500k] 92000/500000 timesteps | episodes: 407 | terminations: 172
# Terminated
# Target position x:  0.2036582662891352
# Target position y:  0.43531085277568715
# Target position z:  0.1821720523826073
# Terminated
# Target position x:  0.21141193522490043
# Target position y:  0.4358421109638146
# Target position z:  0.27897454165070934
# Terminated
# Target position x:  0.014576454411174639
# Target position y:  0.31579549126745576
# Target position z:  0.20909485654480384
# Terminated
# Target position x:  0.01003164872001111
# Target position y:  0.33192234696729744
# Target position z:  0.18551050435077454
# Terminated
# Target position x:  0.15217789440825746
# Target position y:  0.5190746078861792
# Target position z:  0.31475306181987595
# [progressnew_500k] 93000/500000 timesteps | episodes: 413 | terminations: 177
# Terminated
# Target position x:  0.1885943867731015
# Target position y:  0.5888451681101154
# Target position z:  0.2446484205380317
# Terminated
# Target position x:  0.21569766963474127
# Target position y:  0.6220621121906986
# Target position z:  0.26881709885326954
# [progressnew_500k] 94000/500000 timesteps | episodes: 417 | terminations: 179
# Terminated
# Target position x:  0.11541264146679328
# Target position y:  0.3779423442240155
# Target position z:  0.263456298423942
# Terminated
# Target position x:  0.18756234051332404
# Target position y:  0.48168426982056745
# Target position z:  0.2388497126768937
# [progressnew_500k] 95000/500000 timesteps | episodes: 422 | terminations: 181
# Terminated
# Target position x:  0.05886169931332197
# Target position y:  0.6062408574642721
# Target position z:  0.1564262715744856
# Terminated
# Target position x:  0.20499690894101028
# Target position y:  0.35649352015606345
# Target position z:  0.21699055354587618
# Terminated
# Target position x:  0.21722176067864327
# Target position y:  0.5296306265208217
# Target position z:  0.23100440909947303
# Terminated
# Target position x:  0.03143465751871352
# Target position y:  0.3956492108407079
# Target position z:  0.25834806963835
# Terminated
# Target position x:  0.08519655493688197
# Target position y:  0.4843166312544716
# Target position z:  0.19883532717324928
# Terminated
# Target position x:  0.17245077988555155
# Target position y:  0.4937607768030876
# Target position z:  0.210133588660037
# Terminated
# Target position x:  0.13232116142155534
# Target position y:  0.4156576743093562
# Target position z:  0.2936010141347889
# Terminated
# Target position x:  0.21177373869116162
# Target position y:  0.4882280760383395
# Target position z:  0.17469406206223229
# [progressnew_500k] 96000/500000 timesteps | episodes: 429 | terminations: 186
# Terminated
# Target position x:  0.19622123575548173
# Target position y:  0.47883759373742185
# Target position z:  0.2583358131192563
# Terminated
# Target position x:  0.0962768313329653
# Target position y:  0.502088319904381
# Target position z:  0.2806086193657348
# Terminated
# Target position x:  0.04944595829545734
# Target position y:  0.4056752474326885
# Target position z:  0.1710765850847359
# [progressnew_500k] 97000/500000 timesteps | episodes: 434 | terminations: 189
# Terminated
# Target position x:  0.11694681292088352
# Target position y:  0.41981601991871087
# Target position z:  0.29720285050577155
# Terminated
# Target position x:  0.10819362176114433
# Target position y:  0.6135188490938279
# Target position z:  0.3453860648236745
# Terminated
# Target position x:  0.0008354233930088217
# Target position y:  0.3120609335899717
# Target position z:  0.2980942267547375
# Terminated
# Target position x:  0.1931098050454349
# Target position y:  0.5613293873823538
# Target position z:  0.32232387603398027
# Terminated
# Target position x:  0.09113788126953073
# Target position y:  0.642553561685739
# Target position z:  0.28592551112176245
# Terminated
# Target position x:  0.22454564731481788
# Target position y:  0.5907842151185347
# Target position z:  0.17147225522259388
# [progressnew_500k] 98000/500000 timesteps | episodes: 441 | terminations: 195
# Terminated
# Target position x:  0.024575113304306312
# Target position y:  0.4206417489217482
# Target position z:  0.3332775644394989
# Terminated
# Target position x:  0.22418382799575887
# Target position y:  0.4999868521819787
# Target position z:  0.25306414390859505
# Terminated
# Target position x:  0.1986302571095462
# Target position y:  0.5384396200427162
# Target position z:  0.34130737088611107
# Terminated
# Target position x:  0.09560440842921344
# Target position y:  0.6124118351366354
# Target position z:  0.17751724791093382
# Terminated
# Target position x:  0.18996733785168998
# Target position y:  0.477337798834048
# Target position z:  0.3365138722091678
# [progressnew_500k] 99000/500000 timesteps | episodes: 447 | terminations: 200
# Terminated
# Target position x:  0.15501837695925946
# Target position y:  0.6441281236329105
# Target position z:  0.2638567305725088
# Terminated
# Target position x:  0.054572059669395157
# Target position y:  0.4990428321182341
# Target position z:  0.3080807834845892
# Terminated
# Target position x:  0.1645311649215981
# Target position y:  0.4926125006206072
# Target position z:  0.2614312728772021
# [progressnew_500k] 100000/500000 timesteps | episodes: 452 | terminations: 203
# Terminated
# Target position x:  0.07357681684941858
# Target position y:  0.3624983772364711
# Target position z:  0.24481826923040922
# Terminated
# Target position x:  0.22362945864683195
# Target position y:  0.48242016800857634
# Target position z:  0.26817479780474146
# Terminated
# Target position x:  0.029702348883198837
# Target position y:  0.45742406852083506
# Target position z:  0.2692686280835009
# Terminated
# Target position x:  0.1301788156570911
# Target position y:  0.5652864047447871
# Target position z:  0.23680185408130644
# Terminated
# Target position x:  0.1251780563506448
# Target position y:  0.30930195199156124
# Target position z:  0.1898549828458751
# Terminated
# Target position x:  0.07334495462346857
# Target position y:  0.5733025788722768
# Target position z:  0.1784024842594524
# Terminated
# Target position x:  0.01691689631204457
# Target position y:  0.3334890499465827
# Target position z:  0.28557554391429385
# Terminated
# Target position x:  0.0356310855261098
# Target position y:  0.54368035302697
# Target position z:  0.2708917880705819
# Terminated
# Target position x:  0.11100799678420728
# Target position y:  0.530627353577906
# Target position z:  0.26019806998895206
# [progressnew_500k] 101000/500000 timesteps | episodes: 457 | terminations: 207
# Terminated
# Target position x:  0.19967826343308245
# Target position y:  0.5572976563290462
# Target position z:  0.2919992829563177
# Terminated
# Target position x:  0.006496433141520791
# Target position y:  0.6281779346454883
# Target position z:  0.33931448868910397
# Terminated
# Target position x:  0.038242489048557426
# Target position y:  0.5816731563426806
# Target position z:  0.31707922178626713
# [progressnew_500k] 102000/500000 timesteps | episodes: 463 | terminations: 210
# Terminated
# Target position x:  0.19457069741759977
# Target position y:  0.440076730850829
# Target position z:  0.17663010351929198
# Terminated
# Target position x:  0.17939597541903893
# Target position y:  0.4659789798205449
# Target position z:  0.2759232883084656
# Terminated
# Target position x:  0.1326022562838261
# Target position y:  0.5841850746662389
# Target position z:  0.17375687907102852
# Terminated
# Target position x:  0.24246150182400092
# Target position y:  0.35622348288481825
# Target position z:  0.22790590502631256
# [progressnew_500k] 103000/500000 timesteps | episodes: 468 | terminations: 214
# Terminated
# Target position x:  0.14071022180655895
# Target position y:  0.3258419645072529
# Target position z:  0.2350577507933171
# Terminated
# Target position x:  0.20122053914128502
# Target position y:  0.45742052905893227
# Target position z:  0.20702942635243804
# Terminated
# Target position x:  0.09136108775421373
# Target position y:  0.4473425940069353
# Target position z:  0.276219801136824
# Terminated
# Target position x:  0.08456398119464237
# Target position y:  0.4105785390926078
# Target position z:  0.3231954869752704
# [progressnew_500k] 104000/500000 timesteps | episodes: 475 | terminations: 218
# Terminated
# Target position x:  0.019921042466029992
# Target position y:  0.4828675530291929
# Target position z:  0.23720356061015752
# Terminated
# Target position x:  0.24601879474801377
# Target position y:  0.4889499282243381
# Target position z:  0.3007147339207353
# [progressnew_500k] 105000/500000 timesteps | episodes: 479 | terminations: 220
# Terminated
# Target position x:  0.1239414341081696
# Target position y:  0.6060229529194407
# Target position z:  0.30732053819769134
# Terminated
# Target position x:  0.14661411804699448
# Target position y:  0.3674082486896465
# Target position z:  0.2159402776768926
# Terminated
# Target position x:  0.17222012904877607
# Target position y:  0.4891766509631432
# Target position z:  0.17667358202930367
# Terminated
# Target position x:  0.13224619344922103
# Target position y:  0.6143686780359295
# Target position z:  0.3053264445263314
# Terminated
# Target position x:  0.03490863481785891
# Target position y:  0.5109428079039021
# Target position z:  0.16225859784626537
# Terminated
# Target position x:  0.19980025436454596
# Target position y:  0.43270468416243146
# Target position z:  0.262072401217398
# [progressnew_500k] 106000/500000 timesteps | episodes: 483 | terminations: 221
# Terminated
# Target position x:  0.0938017928738766
# Target position y:  0.3693486175109095
# Target position z:  0.32175290864379513
# Terminated
# Target position x:  0.026713361425522192
# Target position y:  0.3441100092251644
# Target position z:  0.1863713839951038
# Terminated
# Target position x:  0.02163153212485272
# Target position y:  0.49958035324467576
# Target position z:  0.2665414874484415
# [progressnew_500k] 107000/500000 timesteps | episodes: 489 | terminations: 224
# Terminated
# Target position x:  0.025777799230275705
# Target position y:  0.42728398434944315
# Target position z:  0.3007095305626881
# Terminated
# Target position x:  0.13091407377083808
# Target position y:  0.5861476318597458
# Target position z:  0.21423670326573166
# Terminated
# Target position x:  0.1081353682047414
# Target position y:  0.34388346243376117
# Target position z:  0.1896282673390294
# Terminated
# Target position x:  0.10300955271534926
# Target position y:  0.47425708436938807
# Target position z:  0.2449505116946814
# [progressnew_500k] 108000/500000 timesteps | episodes: 494 | terminations: 228
# Terminated
# Target position x:  0.03667228700748207
# Target position y:  0.5794210757701586
# Target position z:  0.3268303540738919
# Terminated
# Target position x:  0.06336547478375282
# Target position y:  0.38576843350959694
# Target position z:  0.27638580830004866
# [progressnew_500k] 109000/500000 timesteps | episodes: 497 | terminations: 230
# Terminated
# Target position x:  0.09067562621726463
# Target position y:  0.49598031385657193
# Target position z:  0.21955960119586984
# Terminated
# Target position x:  0.08943633631984468
# Target position y:  0.56006314714479
# Target position z:  0.27741699905495537
# Terminated
# Target position x:  0.1614444868583129
# Target position y:  0.34338736783503765
# Target position z:  0.27168877741786374
# Terminated
# Target position x:  0.04673549549602049
# Target position y:  0.46506938564306294
# Target position z:  0.3170902058244615
# Terminated
# Target position x:  0.1358473497666824
# Target position y:  0.6386969365599557
# Target position z:  0.30482041920543035
# [progressnew_500k] 110000/500000 timesteps | episodes: 504 | terminations: 235
# Terminated
# Target position x:  0.054402669675945536
# Target position y:  0.3342507029067523
# Target position z:  0.24213038439547374
# Terminated
# Target position x:  0.16593817203202152
# Target position y:  0.41275166577537725
# Target position z:  0.2109897971290814
# Terminated
# Target position x:  0.04160967659599665
# Target position y:  0.4440773104964997
# Target position z:  0.3184493288363447
# Terminated
# Target position x:  0.04498341359873073
# Target position y:  0.6207750370392157
# Target position z:  0.32948142868324287
# Terminated
# Target position x:  0.17103814359932534
# Target position y:  0.5709073761978274
# Target position z:  0.3326718398995243
# Terminated
# Target position x:  0.12198719692188198
# Target position y:  0.3936290250835305
# Target position z:  0.15279406731879003
# Terminated
# Target position x:  0.21433994074519805
# Target position y:  0.47277502083336703
# Target position z:  0.1563991901931824
# Terminated
# Target position x:  0.0835749497076359
# Target position y:  0.6440125666280011
# ...
# Target position y:  0.6278151143866092
# Target position z:  0.22649145258016148
# Terminated
# Target position x:  0.09666483613775695
# Target position y:  0.4929473922239448
# Target position z:  0.3439885454002239
# Terminated
# Target position x:  0.23374774398936674
# Target position y:  0.44780416902375497
# Target position z:  0.2116352274352025
# Terminated
# Target position x:  0.23186879176308334
# Target position y:  0.5511641054348653
# Target position z:  0.2977004442218409
# Terminated
# Target position x:  0.15971674341223827
# Target position y:  0.36189261255951694
# Target position z:  0.16017785649355357
# Terminated
# Target position x:  0.05743240437295791
# Target position y:  0.45922609295335226
# Target position z:  0.2588876951612751
# Terminated
# Target position x:  0.016264132225843275
# Target position y:  0.6250240331818695
# Target position z:  0.18388121383277684
# Terminated
# Target position x:  0.17258489966714707
# Target position y:  0.5313751314646249
# Target position z:  0.16593946418346628
# Terminated
# Target position x:  0.03447731577460447
# Target position y:  0.4266311644489116
# Target position z:  0.15579014090011137
# Terminated
# Target position x:  0.17231873645671034
# Target position y:  0.3904317876167495
# Target position z:  0.16292713942298506
# Terminated
# Target position x:  0.19786600574461174
# Target position y:  0.5468148578684149
# Target position z:  0.16933252950903702
# Terminated
# Target position x:  0.21419085321640322
# Target position y:  0.44064593048821427
# Target position z:  0.15682716446433803
# Terminated
# Target position x:  0.03878690271957913
# Target position y:  0.34156143241624165
# Target position z:  0.21748273310480323
# Terminated
# Target position x:  0.04971432783521354
# Target position y:  0.3471399118369523
# Target position z:  0.3111456850449259
# Terminated
# Target position x:  0.23923542847640977
# Target position y:  0.42504199627465244
# Target position z:  0.25911743010614235
# Terminated
# Target position x:  0.013156821372881738
# Target position y:  0.6311251471359289
# Target position z:  0.3253198798919519
# Terminated
# Target position x:  0.12346832222050425
# Target position y:  0.36475868999980043
# Target position z:  0.18666685941338113
# Terminated
# Target position x:  0.07071179849001713
# Target position y:  0.5233567551697212
# Target position z:  0.24834862755034587
# Terminated
# Target position x:  0.12813782708884613
# Target position y:  0.5242375574883757
# Target position z:  0.1835694082131401
# Terminated
# Target position x:  0.14086249958720728
# Target position y:  0.3478194857315272
# Target position z:  0.15479544560183972
# Terminated
# Target position x:  0.18275359912532604
# Target position y:  0.34324412321086456
# Target position z:  0.33206902357137835
# Terminated
# Target position x:  0.04968451314737077
# Target position y:  0.346281096241416
# Target position z:  0.2725723998846253
# Terminated
# Target position x:  0.04812395025225613
# Target position y:  0.6365040680755149
# Target position z:  0.31959705596953253
# Terminated
# Target position x:  0.10521162565028933
# Target position y:  0.3404369676269934
# Target position z:  0.19510307494015547
# Terminated
# Target position x:  0.12263423677776111
# Target position y:  0.47331835525493415
# Target position z:  0.15377069189719308
# Terminated
# Target position x:  0.09996395536683578
# Target position y:  0.6355880154412752
# Target position z:  0.21458514445479493
# Terminated
# Target position x:  0.02345774782150875
# Target position y:  0.36159928135114044
# Target position z:  0.18564439586239143
# Terminated
# Target position x:  0.051545032065101554
# Target position y:  0.4251183550726633
# Target position z:  0.294485272484468
# Terminated
# Target position x:  0.035404457262141614
# Target position y:  0.3153532945528347
# Target position z:  0.22175596121763885
# Terminated
# Target position x:  0.21394979544306264
# Target position y:  0.38511747170420835
# Target position z:  0.29878864264827587
# Terminated
# Target position x:  0.18488242734129687
# Target position y:  0.42002604351131523
# Target position z:  0.17146208701543372
# Terminated
# Target position x:  0.07515719788161371
# Target position y:  0.5994516386778903
# Target position z:  0.17127902808288292
# Terminated
# Target position x:  0.07566099248894723
# Target position y:  0.5076919510202553
# Target position z:  0.2903305788258663
# Terminated
# Target position x:  0.0630768821859887
# Target position y:  0.5767523031211507
# Target position z:  0.3205824322094169
# Terminated
# Target position x:  0.21503444830943186
# Target position y:  0.3066365893435099
# Target position z:  0.20326391377091135
# Terminated
# Target position x:  0.1469246929527493
# Target position y:  0.4497221324979659
# Target position z:  0.21162942945618657
# Terminated
# Target position x:  0.18491857461579503
# Target position y:  0.5206590302685
# Target position z:  0.3275463297299427
# Terminated
# Target position x:  0.24824372290001387
# Target position y:  0.4838057303793185
# Target position z:  0.1913283516262951
# Terminated
# Target position x:  0.23489117486274141
# Target position y:  0.572604372838009
# Target position z:  0.1510484571412389
# Terminated
# Target position x:  0.15394033047794692
# Target position y:  0.6335119784494069
# Target position z:  0.2888984732500221
# [progressnew_500k] 499000/500000 timesteps | episodes: 7323 | terminations: 6569
# Terminated
# Target position x:  0.20249659450997745
# Target position y:  0.5971922373813052
# Target position z:  0.17977659360789555
# Terminated
# Target position x:  0.18034530812073848
# Target position y:  0.5575494174381055
# Target position z:  0.34233214597715683
# Terminated
# Target position x:  0.07792399578378784
# Target position y:  0.3823638722118984
# Target position z:  0.3317811912695455
# Terminated
# Target position x:  0.20825174523671305
# Target position y:  0.5707369857144693
# Target position z:  0.3281852598688217
# Terminated
# Target position x:  0.24241044326740552
# Target position y:  0.42189252006322997
# Target position z:  0.28653503456517293
# Terminated
# Target position x:  0.15254667117691825
# Target position y:  0.4039042569577248
# Target position z:  0.1980499705311555
# Terminated
# Target position x:  0.2181288123684053
# Target position y:  0.5872368318786263
# Target position z:  0.27442346605648704
# Terminated
# Target position x:  0.19699472572224094
# Target position y:  0.5649597853316854
# Target position z:  0.18692650619632026
# Terminated
# Target position x:  0.02130187039581169
# Target position y:  0.474224815931403
# Target position z:  0.15598505258689385
# Terminated
# Target position x:  0.06299180137945826
# Target position y:  0.30629658737071747
# Target position z:  0.18056025798067404
# Terminated
# Target position x:  0.12734345632381977
# Target position y:  0.45418428858381377
# Target position z:  0.2561270707795408
# Terminated
# Target position x:  0.08176537418468513
# Target position y:  0.5158969881401123
# Target position z:  0.18440538370328688
# Terminated
# Target position x:  0.1763148993152737
# Target position y:  0.56877815494411
# Target position z:  0.16542949088739903
# Terminated
# Target position x:  0.06020389178252905
# Target position y:  0.6094224978970597
# Target position z:  0.33758198055902433
# Terminated
# Target position x:  0.16742698151911442
# Target position y:  0.5318085302903808
# Target position z:  0.17616310703122814
# Terminated
# Target position x:  0.07903192553346566
# Target position y:  0.47606252713897956
# Target position z:  0.2854660775702551
# Terminated
# Target position x:  0.054846590732870015
# Target position y:  0.5534389682659824
# Target position z:  0.23675777334861517
# Terminated
# Target position x:  0.02487530421808476
# Target position y:  0.3188742015929609
# Target position z:  0.1960320309240259
# Terminated
# Target position x:  0.1667527558671859
# Target position y:  0.5067439033239294
# Target position z:  0.17351935047373285
# Terminated
# Target position x:  0.030997409033116347
# Target position y:  0.4975133566199911
# Target position z:  0.2981633669963678
# Terminated
# Target position x:  0.07537930053698644
# Target position y:  0.34406698512383455
# Target position z:  0.17368672522429582
# Terminated
# Target position x:  0.20601148122014817
# Target position y:  0.32166726749588903
# Target position z:  0.2779504517771969
# Terminated
# Target position x:  0.09980908280208084
# Target position y:  0.6257906735152899
# Target position z:  0.2454834023216781
# Terminated
# Target position x:  0.23675319224038022
# Target position y:  0.33516380179793726
# Target position z:  0.20392875143468098
# Terminated
# Target position x:  0.11807904915965295
# Target position y:  0.46108722671067287
# Target position z:  0.17257427199315512
# Terminated
# Target position x:  0.15067929228269278
# Target position y:  0.4275942996401364
# Target position z:  0.268841190708016
# Terminated
# Target position x:  0.12106233349737427
# Target position y:  0.3315813383164903
# Target position z:  0.1974509071334295
# Terminated
# Target position x:  0.24096084396895612
# Target position y:  0.3246412402788682
# Target position z:  0.2472668590348957
# Terminated
# Target position x:  0.1759319568471032
# Target position y:  0.4034625550022255
# Target position z:  0.16299028228087478
# Terminated
# Target position x:  0.1131950199159896
# Target position y:  0.4052876722638612
# Target position z:  0.2378964618377916
# Terminated
# Target position x:  0.1603748883659996
# Target position y:  0.43475706751656296
# Target position z:  0.20132970486494942
# Terminated
# Target position x:  0.16787883961767652
# Target position y:  0.6264249791900647
# Target position z:  0.29420293661782665
# Terminated
# Target position x:  0.01826635258188411
# Target position y:  0.6428530318316191
# Target position z:  0.28334065487464866
# Terminated
# Target position x:  0.07679774988473553
# Target position y:  0.32905010471203894
# Target position z:  0.3237399081738766
# Terminated
# Target position x:  0.032135607881725675
# Target position y:  0.5323901796206355
# Target position z:  0.33684380452171486
# Terminated
# Target position x:  0.1528259759106445
# Target position y:  0.3461289818645323
# Target position z:  0.2948024964316329
# Terminated
# Target position x:  0.023992904878416516
# Target position y:  0.6314011269798123
# Target position z:  0.30038430093082885
# Terminated
# Target position x:  0.09205348677232628
# Target position y:  0.36493700744759594
# Target position z:  0.17170604347771537
# Terminated
# Target position x:  0.2000496111126166
# Target position y:  0.6069448304616454
# Target position z:  0.31524078080004087
# Terminated
# Target position x:  0.18721252504030106
# Target position y:  0.4747765396862035
# Target position z:  0.16705942012645658
# Terminated
# Target position x:  0.20860777202313935
# Target position y:  0.3487422878777747
# Target position z:  0.27018452516238056
# Terminated
# Target position x:  0.05091282677540257
# Target position y:  0.39451239826359347
# Target position z:  0.3103826653798002
# Terminated
# Target position x:  0.23086545409788062
# Target position y:  0.4128851491732912
# Target position z:  0.2935535292402609
# Terminated
# Target position x:  0.16500643717614658
# Target position y:  0.44164809022729223
# Target position z:  0.1654067573078662
# Terminated
# Target position x:  0.15963279173860573
# Target position y:  0.36848072074094596
# Target position z:  0.20857245602306193
# Terminated
# Target position x:  0.03632189953747683
# Target position y:  0.6390855376197029
# Target position z:  0.3277459976486612
# Terminated
# Target position x:  0.23823530439082508
# Target position y:  0.3300572539685141
# Target position z:  0.336256239035504
# Terminated
# Target position x:  0.03020839715383067
# Target position y:  0.34000579324240865
# Target position z:  0.3424475193355311
# Terminated
# Target position x:  0.14564624187853448
# Target position y:  0.41171085495166787
# Target position z:  0.27242518422472967
# Terminated
# Target position x:  0.03439460769575631
# Target position y:  0.5117570771523782
# Target position z:  0.2896922042712886
# Terminated
# Target position x:  0.13169028347909228
# Target position y:  0.5723217714406752
# Target position z:  0.16140620060322852
# Terminated
# Target position x:  0.11152992630714606
# Target position y:  0.5800545500893639
# Target position z:  0.17446895213968563
# Terminated
# Target position x:  0.11006822403143732
# Target position y:  0.30611652688500385
# Target position z:  0.20857635444900563
# Terminated
# Target position x:  0.013984131110391373
# Target position y:  0.5211024808653206
# Target position z:  0.2798120904404703
# Terminated
# Target position x:  0.24625806471303635
# Target position y:  0.38060778054527317
# Target position z:  0.3307920206253527
# Terminated
# Target position x:  0.1846348244914495
# Target position y:  0.482918581050542
# Target position z:  0.21962442681673097
# Terminated
# Target position x:  0.003057405542192637
# Target position y:  0.3969218320467435
# Target position z:  0.1991237418481713
# Terminated
# Target position x:  0.2004260694477304
# Target position y:  0.5991566898123171
# Target position z:  0.19451273075733644
# Terminated
# Target position x:  0.16571167078633428
# Target position y:  0.4554596189789297
# Target position z:  0.17087992971745045
# Terminated
# Target position x:  0.024881808831933833
# Target position y:  0.37459679739978147
# Target position z:  0.2654281135182901
# Terminated
# Target position x:  0.22870846661662972
# Target position y:  0.31352588971129364
# Target position z:  0.2020763224490759
# Terminated
# Target position x:  0.17110787285941764
# Target position y:  0.6237856045408339
# Target position z:  0.2860327296233548
# Terminated
# Target position x:  0.09923642870564414
# Target position y:  0.6343698240255524
# Target position z:  0.17292932441777437
# Terminated
# Target position x:  0.15925758563109157
# Target position y:  0.5424873864145501
# Target position z:  0.1703339480263498
# [progressnew_500k] 500000/500000 timesteps | episodes: 7387 | terminations: 6633
# Terminated
# Target position x:  0.11849820890266746
# Target position y:  0.47084201159088424
# Target position z:  0.17199265129886587
# Terminated
# Target position x:  0.11526713301545888
# Target position y:  0.5350947792530647
# Target position z:  0.16669445029758737
# Terminated
# Target position x:  0.09142665623364168
# Target position y:  0.556250662710437
# Target position z:  0.2272250018431232
# Terminated
# Target position x:  0.07283294846319513
# Target position y:  0.33143946448072104
# Target position z:  0.2568447618129224
# Terminated
# Target position x:  0.09734293747379982
# Target position y:  0.6146927907619489
# Target position z:  0.26337011728503684
# Terminated
# Target position x:  0.08132245664372292
# Target position y:  0.42303997688908795
# Target position z:  0.2698007088780761
# Terminated
# Target position x:  0.24992822278527055
# Target position y:  0.532249682885976
# Target position z:  0.21102504510972844
# Terminated
# Target position x:  0.031952858370814435
# Target position y:  0.6089190951226562
# Target position z:  0.2911804208770744
# Terminated
# Target position x:  0.0582663784182792
# Target position y:  0.4990518830263324
# Target position z:  0.3309093787668979
# Terminated
# Target position x:  0.1584988405371872
# Target position y:  0.42523689434747125
# Target position z:  0.2774056742111698
# Terminated
# Target position x:  0.07622633091728079
# Target position y:  0.4099817018456354
# Target position z:  0.28523405241876437
# Terminated
# Target position x:  0.22314773374208502
# Target position y:  0.3355270798327601
# Target position z:  0.3378922649045524
# Terminated
# Target position x:  0.09773140419014203
# Target position y:  0.5707419694519145
# Target position z:  0.1909960988859517
# Terminated
# Target position x:  0.24630093388923732
# Target position y:  0.5222277990042163
# Target position z:  0.18482737480483424
# Terminated
# Target position x:  0.1840438609573963
# Target position y:  0.46417334834273605
# Target position z:  0.19070402869965178
# Terminated
# Target position x:  0.09081505933096476
# Target position y:  0.6387191001344152
# Target position z:  0.1983916013763562
# Terminated
# Target position x:  0.11639053986324391
# Target position y:  0.54837608688226
# Target position z:  0.2274432159255315
# Terminated
# Target position x:  0.10547086453276008
# Target position y:  0.5137652865613188
# Target position z:  0.19229105409390082
# Number of episodes: 7387
# Number of terminations: 6633

# %%
p.disconnect()
